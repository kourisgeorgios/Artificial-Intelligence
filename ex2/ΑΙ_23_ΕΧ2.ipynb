# %% [markdown]
# ## Ομάδα 34
#
# Στοιχεία Μέλους 1: Γεώργιος Κουρής 03120116
#
# Στοιχεία Μέλους 2: Αθανάσιος Αθανασόπουλος 03120820

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Mounted at /content/drive

# %%
# !pip install pyswip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyswip
#   Downloading pyswip-0.2.10-py2.py3-none-any.whl (27 kB)
# Installing collected packages: pyswip
# Successfully installed pyswip-0.2.10

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
path = '/content/drive/MyDrive/AI_6/ex2/' #path for google drive
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

# %%
#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title')) #getattr returns the value of the named attribute

  for genre in getattr(row, 'genres').split('|'):
    literals.append("genre('"+ movie_title +"','"+ genre +"')")
  
  for production_company in list(eval(getattr(row, 'production_companies'))):
    production_company = production_company["name"].replace("'", "")
    literals.append("production_company('"+ movie_title +"','"+ production_company +"')")

  for plot_keyword in getattr(row, 'plot_keywords').split("|"):
    plot_keyword = plot_keyword.replace("'", "")
    literals.append("plot_keyword('"+ movie_title +"','"+ plot_keyword +"')")

  literals.append("language('"+ movie_title +"','"+ clean_text(getattr(row, 'language')) +"')")
  literals.append("country('"+ movie_title +"','"+ clean_text(getattr(row, 'country')) +"')")
  literals.append("director_name('"+ movie_title +"','"+ clean_text(getattr(row, 'director_name')) +"')")
  literals.append("actor_name('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_1_name')) +"')")
  literals.append("actor_name('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_2_name')) +"')")
  literals.append("actor_name('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_3_name')) +"')")
  
  if(getattr(row, 'title_year') != "UNK"):
    year = int(getattr(row, 'title_year'))
    literals.append("decade('"+ movie_title +"','"+ str(year-year%10) +"')")

# %%
literals.sort() # we sort the literals list (prolog requirement)

# %%
for literal in literals:
  prolog.assertz(literal)
# print (literal +'.')

# Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
prolog.consult(path + "db.pl") #we consult the db file we have already created (it is in the uploaded zip file)

# %% [markdown]
# ### Το περιεχόμενο του αρχείου db.pl φαίνεται και παρακάτω:
# /*1-Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές) -> 1 OR 3 */
#
# same_genre(X, Y, G1) :- genre(X, G1), genre(Y, G1), X \= Y.
#
# /*2-Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)*/
#
# same_genre_3(X, Y) :- same_genre(X, Y, G1), same_genre(X, Y, G2), same_genre(X, Y, G3), G1 \= G2, G1 \= G3, G2 \= G3.
#
# /*3-Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)*/
#
# same_genre_1(X, Y) :- same_genre(X, Y, G1).
#
# /*4-Κοινός σκηνοθέτης*/
#
# same_director(X, Y) :- director_name(X, S), director_name(Y, S), X \= Y.
#
# /*PLOT*/
#
# same_word(X, Y, W) :- plot_keyword(X, W), plot_keyword(Y, W), X \= Y.
#
# /*5-Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)*/
#
# same_plot_3(X, Y) :- same_word(X, Y, P1), same_word(X, Y, P2), same_word(X, Y, P3), P1 \= P2, P1 \= P3, P2 \= P3.
#
# /*6-Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)*/
#
# same_plot_2(X, Y) :- same_word(X, Y, P1), same_word(X, Y, P2), P1 \= P2.
#
# /*7-Ίδιους τους βασικούς ηθοποιούς (και τους 3)*/
#
# same_actor(X, Y, Q) :- actor_name(X, Q), actor_name(Y, Q), X \= Y.
#
# same_actor_3(X, Y) :- same_actor(X, Y, Q1), same_actor(X, Y, Q2), same_actor(X, Y, Q3), Q1 \= Q2, Q1 \= Q3, Q2 \= Q3.
#
# /*8-Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)*/
#
# same_actor_2(X, Y) :- same_actor(X, Y, Q1), same_actor(X, Y, Q2), Q1 \= Q2.
#
# /*9-Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)*/
#
# same_actor_1(X, Y) :- same_actor(X, Y, Q1).
#
# /*10-Ίδια γλώσσα*/
#
# same_language(X, Y) :- language(X, L), language(Y, L), X \= Y.
#
# /*11-Είναι έγχρωμες ή ασπρόμαυρες*/
#
# black_and_white(X) :- plot_keyword(X, "black and white").
#
# /*12-Κοινό studio παραγωγής*/
#
# same_production_company(X, Y):- production_company(X, P), production_company(Y, P), X \= Y.
#
# /*13-Κοινή χώρα παραγωγής */
#
# same_country(X, Y) :- country(X, C), country(Y, C), X \= Y.
#
# /*14-Ίδια δεκαετία */
#
# same_decade(X, Y) :- decade(X, T), decade(Y, T), X \= Y.
#
# /*find_sim*/
#
# find_sim_1(X, Y) :- same_genre_1(X, Y).
#
# find_sim_2(X, Y) :- same_genre_3(X, Y).
#
# find_sim_3(X, Y) :- find_sim_2(X, Y), same_plot_2(X, Y).
#
# find_sim_4(X, Y) :- find_sim_2(X, Y), same_plot_3(X, Y).
#
# find_sim_5(X, Y) :- find_sim_3(X, Y), same_country(X, Y), same_language(X, Y).
#
# find_sim_6(X, Y) :- find_sim_5(X, Y), same_production_company(X, Y), same_decade(X, Y).

# %% [markdown]
# ### Μερικά ενδεικτικά παραδείγματα:

# %%
quer1 = prolog.query("same_actor_1('#Horror', M)") # we test the movie #Horror, by finding movies with 1 similar actor at least
for res1 in quer1: print(res1)
quer1.close()
# Out:
# {'M': 'Antibirth'}
# {'M': 'Barry Munday'}
# {'M': 'Boys Dont Cry'}
# {'M': 'Kids'}
# {'M': 'Party Monster'}
# {'M': 'Shattered Glass'}
# {'M': 'The Brown Bunny'}
# {'M': 'Trees Lounge'}
# {'M': 'Everyone Says I Love You'}

# %%
quer2 = prolog.query("same_country('Kids', M)")
for res2 in quer2: print(res2)
quer2.close()
# Out:
# {'M': '#Horror'}
# {'M': '(500) Days of Summer'}
# {'M': '10 Cloverfield Lane'}
# {'M': '10 Days in a Madhouse'}
# {'M': '10 Things I Hate About You'}
# {'M': '102 Dalmatians'}
# {'M': '10th & Wolf'}
# {'M': '12 Angry Men'}
# {'M': '12 Rounds'}
# {'M': '12 Years a Slave'}
# {'M': '13 Going on 30'}
# {'M': '1408'}
# {'M': '16 Blocks'}
# {'M': '17 Again'}
# {'M': '1776'}
# {'M': '1941'}
# {'M': '1982'}
# {'M': '2 Fast 2 Furious'}
# {'M': '2 Guns'}
# {'M': '20 Dates'}
# {'M': '20 Feet from Stardom'}
# {'M': '20,000 Leagues Under the Sea'}
# {'M': '200 Cigarettes'}
# {'M': '2001: A Space Odyssey'}
# {'M': '2016: Obamas America'}
# {'M': '21 & Over'}
# {'M': '21 Grams'}
# {'M': '21 Jump Street'}
# {'M': '21'}
# {'M': '22 Jump Street'}
# {'M': '25th Hour'}
# {'M': '27 Dresses'}
# {'M': '28 Days'}
# {'M': '2:13'}
# {'M': '3 Backyards'}
# {'M': '3 Strikes'}
# {'M': '30 Minutes or Less'}
# {'M': '30 Nights of Paranormal Activity With the Devil Inside the Girl With the Dragon Tattoo'}
# {'M': '300'}
# {'M': '3000 Miles to Graceland'}
# {'M': '300: Rise of an Empire'}
# {'M': '3:10 to Yuma'}
# {'M': '40 Days and 40 Nights'}
# {'M': '42'}
# {'M': '42nd Street'}
# {'M': '47 Ronin'}
# {'M': '5 Days of War'}
# {'M': '50 First Dates'}
# {'M': '50/50'}
# {'M': '54'}
# {'M': '55 Days at Peking'}
# {'M': '8 Days'}
# {'M': '8 Mile'}
# {'M': '88 Minutes'}
# {'M': '8MM'}
# {'M': '9'}
# {'M': '90 Minutes in Heaven'}
# {'M': 'A Beautiful Mind'}
# {'M': 'A Better Life'}
# {'M': 'A Bugs Life'}
# {'M': 'A Charlie Brown Christmas'}
# {'M': 'A Christmas Carol'}
# {'M': 'A Christmas Story'}
# {'M': 'A Civil Action'}
# {'M': 'A Farewell to Arms'}
# {'M': 'A Few Good Men'}
# {'M': 'A Good Day to Die Hard'}
# {'M': 'A Good Year'}
# {'M': 'A Guy Named Joe'}
# {'M': 'A Guy Thing'}
# {'M': 'A Haunted House 2'}
# {'M': 'A Haunted House'}
# {'M': 'A History of Violence'}
# {'M': 'A Home at the End of the World'}
# {'M': 'A Knights Tale'}
# {'M': 'A LEGO Brickumentary'}
# {'M': 'A League of Their Own'}
# {'M': 'A Lot Like Love'}
# {'M': 'A Low Down Dirty Shame'}
# {'M': 'A Madea Christmas'}
# {'M': 'A Mighty Wind'}
# {'M': 'A Million Ways to Die in the West'}
# {'M': 'A Night at the Roxbury'}
# {'M': 'A Nightmare on Elm Street 3: Dream Warriors'}
# {'M': 'A Nightmare on Elm Street 4: The Dream Master'}
# {'M': 'A Nightmare on Elm Street 5: The Dream Child'}
# {'M': 'A Nightmare on Elm Street Part 2: Freddys Revenge'}
# {'M': 'A Nightmare on Elm Street'}
# {'M': 'A Perfect Getaway'}
# {'M': 'A Prairie Home Companion'}
# {'M': 'A Scanner Darkly'}
# {'M': 'A Serious Man'}
# {'M': 'A Simple Plan'}
# {'M': 'A Simple Wish'}
# {'M': 'A Single Man'}
# {'M': 'A Streetcar Named Desire'}
# {'M': 'A Thin Line Between Love and Hate'}
# {'M': 'A Thousand Words'}
# {'M': 'A Time to Kill'}
# {'M': 'A Very Harold & Kumar Christmas'}
# {'M': 'A Walk Among the Tombstones'}
# {'M': 'A Walk to Remember'}
# {'M': 'A.I. Artificial Intelligence'}
# {'M': 'ATL'}
# {'M': 'AWOL-72'}
# {'M': 'Abduction'}
# {'M': 'About Last Night'}
# {'M': 'About Schmidt'}
# {'M': 'Abraham Lincoln: Vampire Hunter'}
# {'M': 'Absentia'}
# {'M': 'Absolute Power'}
# {'M': 'Accidental Love'}
# {'M': 'Ace Ventura: Pet Detective'}
# {'M': 'Ace Ventura: When Nature Calls'}
# {'M': 'Across the Universe'}
# {'M': 'Act of Valor'}
# {'M': 'Action Jackson'}
# {'M': 'Adam'}
# {'M': 'Adaptation.'}
# {'M': 'Addicted'}
# {'M': 'Admission'}
# {'M': 'Adventureland'}
# {'M': 'After Earth'}
# {'M': 'After the Sunset'}
# {'M': 'After'}
# {'M': 'After.Life'}
# {'M': 'Agent Cody Banks 2: Destination London'}
# {'M': 'Airborne'}
# {'M': 'Airplane!'}
# {'M': 'Akeelah and the Bee'}
# {'M': 'Aladdin'}
# {'M': 'Albino Alligator'}
# {'M': 'Alex & Emma'}
# {'M': 'Alex Cross'}
# {'M': 'Alexander and the Terrible, Horrible, No Good, Very Bad Day'}
# {'M': 'Alexanders Ragtime Band'}
# {'M': 'Ali'}
# {'M': 'Alice in Wonderland'}
# {'M': 'Alien Zone'}
# {'M': 'Alien'}
# {'M': 'Alien: Resurrection'}
# {'M': 'Aliens vs Predator: Requiem'}
# {'M': 'Alive'}
# {'M': 'All About Steve'}
# {'M': 'All About the Benjamins'}
# {'M': 'All Good Things'}
# {'M': 'All Is Bright'}
# {'M': 'All Is Lost'}
# {'M': 'All That Jazz'}
# {'M': 'All the Boys Love Mandy Lane'}
# {'M': 'All the Kings Men'}
# {'M': 'All the Pretty Horses'}
# {'M': 'All the Real Girls'}
# {'M': 'Allegiant'}
# {'M': 'Alleluia! The Devils Carnival'}
# {'M': 'Almost Famous'}
# {'M': 'Aloha'}
# {'M': 'Alone With Her'}
# {'M': 'Along Came Polly'}
# {'M': 'Along the Roadside'}
# {'M': 'Alpha and Omega'}
# {'M': 'Alpha and Omega: The Legend of the Saw Tooth Cave'}
# {'M': 'Alvin and the Chipmunks'}
# {'M': 'Alvin and the Chipmunks: Chipwrecked'}
# {'M': 'Alvin and the Chipmunks: The Road Chip'}
# {'M': 'Alvin and the Chipmunks: The Squeakquel'}
# {'M': 'Amadeus'}
# {'M': 'American Beast'}
# {'M': 'American Beauty'}
# {'M': 'American Desi'}
# {'M': 'American Dreamz'}
# {'M': 'American Graffiti'}
# {'M': 'American Hero'}
# {'M': 'American History X'}
# {'M': 'American Hustle'}
# {'M': 'American Ninja 2: The Confrontation'}
# {'M': 'American Outlaws'}
# {'M': 'American Pie 2'}
# {'M': 'American Pie'}
# {'M': 'American Reunion'}
# {'M': 'American Sniper'}
# {'M': 'American Splendor'}
# {'M': 'American Wedding'}
# {'M': 'Americas Sweethearts'}
# {'M': 'Amidst the Devils Wings'}
# {'M': 'Amigo'}
# {'M': 'Amistad'}
# {'M': 'Amnesiac'}
# {'M': 'An Alan Smithee Film: Burn, Hollywood, Burn'}
# {'M': 'An American Carol'}
# {'M': 'An American in Hollywood'}
# {'M': 'An Everlasting Piece'}
# {'M': 'An Inconvenient Truth'}
# {'M': 'An Unfinished Life'}
# {'M': 'Anacondas: The Hunt for the Blood Orchid'}
# {'M': 'Anastasia'}
# {'M': 'Anchorman 2: The Legend Continues'}
# {'M': 'Anchorman: The Legend of Ron Burgundy'}
# {'M': 'And So It Goes'}
# {'M': 'Andersons Cross'}
# {'M': 'Angel Eyes'}
# {'M': 'Animal House'}
# {'M': 'Animals'}
# {'M': 'Annabelle'}
# {'M': 'Anne of Green Gables'}
# {'M': 'Annie Get Your Gun'}
# {'M': 'Annie Hall'}
# {'M': 'Annie'}
# {'M': 'Anomalisa'}
# {'M': 'Another Earth'}
# {'M': 'Another Happy Day'}
# {'M': 'Ant-Man'}
# {'M': 'Antarctic Edge: 70° South'}
# {'M': 'Antibirth'}
# {'M': 'Antwone Fisher'}
# {'M': 'Antz'}
# {'M': 'Any Given Sunday'}
# {'M': 'Anywhere But Here'}
# {'M': 'Apocalypse Now'}
# {'M': 'Apocalypto'}
# {'M': 'Apollo 13'}
# {'M': 'Appaloosa'}
# {'M': 'Aqua Teen Hunger Force Colon Movie Film for Theaters'}
# {'M': 'Arachnophobia'}
# {'M': 'Arbitrage'}
# {'M': 'Archaeology of a Woman'}
# {'M': 'Are We There Yet?'}
# {'M': 'Area 51'}
# {'M': 'Argo'}
# {'M': 'Arlington Road'}
# {'M': 'Armageddon'}
# {'M': 'Armored'}
# {'M': 'Army of Darkness'}
# {'M': 'Aroused'}
# {'M': 'Arthur Christmas'}
# {'M': 'As Above, So Below'}
# {'M': 'As Good as It Gets'}
# {'M': 'Ask Me Anything'}
# {'M': 'Assault on Precinct 13'}
# {'M': 'At First Sight'}
# {'M': 'Atlantis: The Lost Empire'}
# {'M': 'Atlas Shrugged Part II'}
# {'M': 'Atlas Shrugged Part III: Who is John Galt?'}
# {'M': 'August Rush'}
# {'M': 'August: Osage County'}
# {'M': 'Austin Powers in Goldmember'}
# {'M': 'Austin Powers: The Spy Who Shagged Me'}
# {'M': 'Auto Focus'}
# {'M': 'Autumn in New York'}
# {'M': 'Avatar'}
# {'M': 'Avengers: Age of Ultron'}
# {'M': 'Awake'}
# {'M': 'Away We Go'}
# {'M': 'B-Girl'}
# {'M': 'Baby Boy'}
# {'M': 'Baby Geniuses'}
# {'M': 'Baby Mama'}
# {'M': 'Babys Day Out'}
# {'M': 'Bachelorette'}
# {'M': 'Back to the Future Part II'}
# {'M': 'Back to the Future Part III'}
# {'M': 'Back to the Future'}
# {'M': 'Backmask'}
# {'M': 'Bad Boys II'}
# {'M': 'Bad Boys'}
# {'M': 'Bad Company'}
# {'M': 'Bad Grandpa'}
# {'M': 'Bad Moms'}
# {'M': 'Bad Teacher'}
# {'M': 'Bad Words'}
# {'M': 'Baggage Claim'}
# {'M': 'Baghead'}
# {'M': 'Bambi'}
# {'M': 'Bamboozled'}
# {'M': 'Bananas'}
# {'M': 'Bandidas'}
# {'M': 'Bandits'}
# {'M': 'Bandslam'}
# {'M': 'Bang'}
# {'M': 'Bangkok Dangerous'}
# {'M': 'Banshee Chapter'}
# {'M': 'Barbarella'}
# {'M': 'Barbershop 2:  Back in Business'}
# {'M': 'Barbershop'}
# {'M': 'Barneys Great Adventure'}
# {'M': 'Barry Munday'}
# {'M': 'Basic'}
# {'M': 'Basquiat'}
# {'M': 'Bathing Beauty'}
# {'M': 'Batman v Superman: Dawn of Justice'}
# {'M': 'Batman'}
# {'M': 'Batman: The Dark Knight Returns, Part 2'}
# {'M': 'Bats'}
# {'M': 'Battle for the Planet of the Apes'}
# {'M': 'Battle of the Year'}
# {'M': 'Battle: Los Angeles'}
# {'M': 'Battlefield Earth'}
# {'M': 'Battleship'}
# {'M': 'Be Cool'}
# {'M': 'Be Kind Rewind'}
# {'M': 'Beastly'}
# {'M': 'Beastmaster 2: Through the Portal of Time'}
# {'M': 'Beasts of the Southern Wild'}
# {'M': 'Beautiful Creatures'}
# {'M': 'Beauty Shop'}
# {'M': 'Beavis and Butt-Head Do America'}
# {'M': 'Because I Said So'}
# {'M': 'Because of Winn-Dixie'}
# {'M': 'Bedazzled'}
# {'M': 'Bedtime Stories'}
# {'M': 'Bee Movie'}
# {'M': 'Beer League'}
# {'M': 'Beerfest'}
# {'M': 'Beetlejuice'}
# {'M': 'Before Sunset'}
# {'M': 'Begin Again'}
# {'M': 'Beginners'}
# {'M': 'Behind Enemy Lines'}
# {'M': 'Being John Malkovich'}
# {'M': 'Beloved'}
# {'M': 'Ben-Hur'}
# {'M': 'Beneath the Planet of the Apes'}
# {'M': 'Benji'}
# {'M': 'Beowulf'}
# {'M': 'Bernie'}
# {'M': 'Best in Show'}
# {'M': 'Better Luck Tomorrow'}
# {'M': 'Beverly Hills Chihuahua'}
# {'M': 'Beverly Hills Cop II'}
# {'M': 'Beverly Hills Cop III'}
# {'M': 'Beverly Hills Cop'}
# {'M': 'Beyond the Lights'}
# {'M': 'Beyond the Mat'}
# {'M': 'Beyond the Valley of the Dolls'}
# {'M': 'Big Daddy'}
# {'M': 'Big Fat Liar'}
# {'M': 'Big Fish'}
# {'M': 'Big Hero 6'}
# {'M': 'Big Mommas House 2'}
# {'M': 'Big Mommas: Like Father, Like Son'}
# {'M': 'Big Trouble in Little China'}
# {'M': 'Big Trouble'}
# {'M': 'Big'}
# {'M': 'Bill & Teds Bogus Journey'}
# {'M': 'Bill & Teds Excellent Adventure'}
# {'M': 'Birdman'}
# {'M': 'Bizarre'}
# {'M': 'Black Knight'}
# {'M': 'Black Nativity'}
# {'M': 'Black November'}
# {'M': 'Black Rain'}
# {'M': 'Black Rock'}
# {'M': 'Black Snake Moan'}
# {'M': 'Black Swan'}
# {'M': 'Black Water Transit'}
# {'M': 'Black or White'}
# {'M': 'Blackhat'}
# {'M': 'Blade Runner'}
# {'M': 'Blade'}
# {'M': 'Blade: Trinity'}
# {'M': 'Blades of Glory'}
# {'M': 'Blast from the Past'}
# {'M': 'Blazing Saddles'}
# {'M': 'Blended'}
# {'M': 'Bless the Child'}
# {'M': 'Blonde Ambition'}
# {'M': 'Blood Work'}
# {'M': 'BloodRayne'}
# {'M': 'Bloodsport'}
# {'M': 'Blow Out'}
# {'M': 'Blow'}
# {'M': 'Blue Jasmine'}
# {'M': 'Blue Like Jazz'}
# {'M': 'Blue Ruin'}
# {'M': 'Blue Valentine'}
# {'M': 'Bobby Jones: Stroke of Genius'}
# {'M': 'Bobby'}
# {'M': 'Body Double'}
# {'M': 'Body of Lies'}
# {'M': 'Bogus'}
# {'M': 'Boiler Room'}
# {'M': 'Bolt'}
# {'M': 'Boogeyman'}
# {'M': 'Boogie Nights'}
# {'M': 'Book of Shadows: Blair Witch 2'}
# {'M': 'Boom Town'}
# {'M': 'Boomerang'}
# {'M': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan'}
# {'M': 'Born on the Fourth of July'}
# {'M': 'Born to Fly: Elizabeth Streb vs. Gravity'}
# {'M': 'Bottle Rocket'}
# {'M': 'Bottle Shock'}
# {'M': 'Bound by Honor'}
# {'M': 'Bound'}
# {'M': 'Bowfinger'}
# {'M': 'Bowling for Columbine'}
# {'M': 'Boyhood'}
# {'M': 'Boys Dont Cry'}
# {'M': 'Boys and Girls'}
# {'M': 'Boyz n the Hood'}
# {'M': 'Brave New Girl'}
# {'M': 'Brave'}
# {'M': 'Braveheart'}
# {'M': 'Breakdown'}
# {'M': 'Breakfast of Champions'}
# {'M': 'Breakin All the Rules'}
# {'M': 'Breaking Upwards'}
# {'M': 'Bride Wars'}
# {'M': 'Bridesmaids'}
# {'M': 'Bridge to Terabithia'}
# {'M': 'Brigham City'}
# {'M': 'Bring It On'}
# {'M': 'Bringing Down the House'}
# {'M': 'Bringing Out the Dead'}
# {'M': 'Brokedown Palace'}
# {'M': 'Broken Arrow'}
# {'M': 'Broken City'}
# {'M': 'Broken Horses'}
# {'M': 'Brooklyn Rules'}
# {'M': 'Brooklyns Finest'}
# {'M': 'Brothers'}
# {'M': 'Bruce Almighty'}
# {'M': 'Brüno'}
# {'M': 'Bubba Ho-tep'}
# {'M': 'Bubble Boy'}
# {'M': 'Bucky Larson: Born to Be a Star'}
# {'M': 'Buffalo 66'}
# {'M': 'Bulletproof Monk'}
# {'M': 'Bullets Over Broadway'}
# {'M': 'Bulworth'}
# {'M': 'Burlesque'}
# {'M': 'Burn After Reading'}
# {'M': 'Burn'}
# {'M': 'Burnt'}
# {'M': 'But Im a Cheerleader'}
# {'M': 'Butch Cassidy and the Sundance Kid'}
# {'M': 'Butterfly Girl'}
# {'M': 'Butterfly'}
# {'M': 'C.H.U.D.'}
# {'M': 'Ca$h'}
# {'M': 'Cabin Fever'}
# {'M': 'Caddyshack'}
# {'M': 'Cadillac Records'}
# {'M': 'Cant Hardly Wait'}
# {'M': 'Cant Stop the Music'}
# {'M': 'Cape Fear'}
# {'M': 'Capitalism: A Love Story'}
# {'M': 'Captain America: Civil War'}
# {'M': 'Captain America: The First Avenger'}
# {'M': 'Captain America: The Winter Soldier'}
# {'M': 'Captain Phillips'}
# {'M': 'Captive'}
# {'M': 'Caravans'}
# {'M': 'Carousel of Revenge'}
# {'M': 'Carrie'}
# {'M': 'Carriers'}
# {'M': 'Cars 2'}
# {'M': 'Cars'}
# {'M': 'Casa De Mi Padre'}
# {'M': 'Casablanca'}
# {'M': 'Casper'}
# {'M': 'Cast Away'}
# {'M': 'Cat People'}
# {'M': 'Cat on a Hot Tin Roof'}
# {'M': 'Catch Me If You Can'}
# {'M': 'Catch That Kid'}
# {'M': 'Catch-22'}
# {'M': 'Cats & Dogs 2 : The Revenge of Kitty Galore'}
# {'M': 'Cats & Dogs'}
# {'M': 'Cats Dont Dance'}
# {'M': 'Catwoman'}
# {'M': 'Cedar Rapids'}
# {'M': 'Celebrity'}
# {'M': 'Celeste & Jesse Forever'}
# {'M': 'Center Stage'}
# {'M': 'Central Intelligence'}
# {'M': 'Chain Letter'}
# {'M': 'Chain Reaction'}
# {'M': 'Chain of Command'}
# {'M': 'Chairman of the Board'}
# {'M': 'Changeling'}
# {'M': 'Changing Lanes'}
# {'M': 'Charlie Bartlett'}
# {'M': 'Charlie St. Cloud'}
# {'M': 'Charlie Wilsons War'}
# {'M': 'Charlies Angels'}
# {'M': 'Charlies Angels: Full Throttle'}
# {'M': 'Charly'}
# {'M': 'Chasing Amy'}
# {'M': 'Chasing Mavericks'}
# {'M': 'Chasing Papi'}
# {'M': 'Cheap Thrills'}
# {'M': 'Cheaper by the Dozen 2'}
# {'M': 'Cheaper by the Dozen'}
# {'M': 'Checkmate'}
# {'M': 'Chernobyl Diaries'}
# {'M': 'Chicago Overcoat'}
# {'M': 'Chicago'}
# {'M': 'Chicken Little'}
# {'M': 'Childless'}
# {'M': 'Childs Play 2'}
# {'M': 'Childs Play'}
# {'M': 'Chill Factor'}
# {'M': 'Choke'}
# {'M': 'Christmas Eve'}
# {'M': 'Christmas Mail'}
# {'M': 'Christmas with the Kranks'}
# {'M': 'Chronicle'}
# {'M': 'Chuck & Buck'}
# {'M': 'Cinderella Man'}
# {'M': 'Circle'}
# {'M': 'Cirque du Freak: The Vampires Assistant'}
# {'M': 'Cirque du Soleil: Worlds Away'}
# {'M': 'City By The Sea'}
# {'M': 'City Hall'}
# {'M': 'City Island'}
# {'M': 'City of Angels'}
# {'M': 'City of Ember'}
# {'M': 'City of Ghosts'}
# {'M': 'Civil Brand'}
# {'M': 'Clash of the Titans'}
# {'M': 'Clear and Present Danger'}
# {'M': 'Clerks II'}
# {'M': 'Clerks'}
# {'M': 'Click'}
# {'M': 'Clockstoppers'}
# {'M': 'Close Encounters of the Third Kind'}
# {'M': 'Close Range'}
# {'M': 'Closer'}
# {'M': 'Cloudy with a Chance of Meatballs 2'}
# {'M': 'Cloudy with a Chance of Meatballs'}
# {'M': 'Cloverfield'}
# {'M': 'Club Dread'}
# {'M': 'Clueless'}
# {'M': 'Coal Miners Daughter'}
# {'M': 'Code Name: The Cleaner'}
# {'M': 'Code of Honor'}
# {'M': 'Coffee Town'}
# {'M': 'Cold Mountain'}
# {'M': 'Collateral Damage'}
# {'M': 'Collateral'}
# {'M': 'College'}
# {'M': 'Come Early Morning'}
# {'M': 'Commando'}
# {'M': 'Compliance'}
# {'M': 'Con Air'}
# {'M': 'Conan the Barbarian'}
# {'M': 'Conan the Destroyer'}
# {'M': 'Confessions of a Dangerous Mind'}
# {'M': 'Congo'}
# {'M': 'Connie and Carla'}
# {'M': 'Conquest of the Planet of the Apes'}
# {'M': 'Conspiracy Theory'}
# {'M': 'Contact'}
# {'M': 'Contagion'}
# {'M': 'Contraband'}
# {'M': 'Cool Runnings'}
# {'M': 'Cop Land'}
# {'M': 'Cop Out'}
# {'M': 'Copycat'}
# {'M': 'Coraline'}
# {'M': 'Corky Romano'}
# {'M': 'Corpse Bride'}
# {'M': 'Counting'}
# {'M': 'Country Strong'}
# {'M': 'Couples Retreat'}
# {'M': 'Courage Under Fire'}
# {'M': 'Courageous'}
# {'M': 'Coyote Ugly'}
# {'M': 'Cradle 2 the Grave'}
# {'M': 'Cradle Will Rock'}
# {'M': 'Crank'}
# {'M': 'Crank: High Voltage'}
# {'M': 'Crazy Heart'}
# {'M': 'Crazy in Alabama'}
# {'M': 'Crazy, Stupid, Love.'}
# {'M': 'Crazy/Beautiful'}
# {'M': 'Creative Control'}
# {'M': 'Creature'}
# {'M': 'Creed'}
# {'M': 'Creepshow 2'}
# {'M': 'Creepshow'}
# {'M': 'Criminal Activities'}
# {'M': 'Crimson Tide'}
# {'M': 'Critical Care'}
# {'M': 'Crooklyn'}
# {'M': 'Crossover'}
# {'M': 'Crossroads'}
# {'M': 'Cruel Intentions'}
# {'M': 'Cry_Wolf'}
# {'M': 'Curious George'}
# {'M': 'Cypher'}
# {'M': 'Cyrus'}
# {'M': 'D-Tox'}
# {'M': 'D.E.B.S.'}
# {'M': 'Da Sweet Blood of Jesus'}
# {'M': 'Daddy Day Camp'}
# {'M': 'Daddy Day Care'}
# {'M': 'Daddys Home'}
# {'M': 'Dallas Buyers Club'}
# {'M': 'Damnation Alley'}
# {'M': 'Damsels in Distress'}
# {'M': 'Dance Flick'}
# {'M': 'Dancer, Texas Pop. 81'}
# {'M': 'Dancin Its On'}
# {'M': 'Danny Collins'}
# {'M': 'Dantes Peak'}
# {'M': 'Dark Water'}
# {'M': 'Darling Companion'}
# {'M': 'Darling Lili'}
# {'M': 'Date Night'}
# {'M': 'Dave Chappelles Block Party'}
# {'M': 'Dawn of the Dead'}
# {'M': 'Dawn of the Planet of the Apes'}
# {'M': 'Day of the Dead'}
# {'M': 'Daybreakers'}
# {'M': 'Daylight'}
# {'M': 'Days of Heaven'}
# {'M': 'Days of Thunder'}
# {'M': 'Dazed and Confused'}
# {'M': 'Dead Like Me: Life After Death'}
# {'M': 'Dead Man Down'}
# {'M': 'Dead Man Walking'}
# {'M': 'Dead Man on Campus'}
# {'M': 'Dead Poets Society'}
# {'M': 'Deadline - U.S.A.'}
# {'M': 'Deadpool'}
# {'M': 'Dear John'}
# {'M': 'Death Becomes Her'}
# {'M': 'Death Race 2000'}
# {'M': 'Death Sentence'}
# {'M': 'Deceptive Practice: The Mysteries and Mentors of Ricky Jay'}
# {'M': 'Deck the Halls'}
# {'M': 'Deconstructing Harry'}
# {'M': 'Deep Impact'}
# {'M': 'Def Jams How to Be a Player'}
# {'M': 'Delgo'}
# {'M': 'Deliver Us from Evil'}
# {'M': 'Delivery Man'}
# {'M': 'Desert Blue'}
# {'M': 'Desperado'}
# {'M': 'Despicable Me 2'}
# {'M': 'Despicable Me'}
# {'M': 'Detention of the Dead'}
# {'M': 'Detention'}
# {'M': 'Deterrence'}
# {'M': 'Detroit Rock City'}
# {'M': 'Deuce Bigalow: European Gigolo'}
# {'M': 'Deuce Bigalow: Male Gigolo'}
# {'M': 'Devil'}
# {'M': 'Devils Due'}
# {'M': 'Diary of a Wimpy Kid: Dog Days'}
# {'M': 'Diary of a Wimpy Kid: Rodrick Rules'}
# {'M': 'Diary of the Dead'}
# {'M': 'Dick Tracy'}
# {'M': 'Dickie Roberts: Former Child Star'}
# {'M': 'Did You Hear About the Morgans?'}
# {'M': 'Die Hard 2'}
# {'M': 'Die Hard'}
# {'M': 'Die Hard: With a Vengeance'}
# {'M': 'Diner'}
# {'M': 'Dinner Rush'}
# {'M': 'Dinner for Schmucks'}
# {'M': 'Dinosaur'}
# {'M': 'Dirty Grandpa'}
# {'M': 'Disaster Movie'}
# {'M': 'Disclosure'}
# {'M': 'District 9'}
# {'M': 'Disturbia'}
# {'M': 'Divergent'}
# {'M': 'Divine Secrets of the Ya-Ya Sisterhood'}
# {'M': 'Django Unchained'}
# {'M': 'Do You Believe?'}
# {'M': 'Do the Right Thing'}
# {'M': 'Doc Hollidays Revenge'}
# {'M': 'Doctor Dolittle'}
# {'M': 'Dogma'}
# {'M': 'Dogtown and Z-Boys'}
# {'M': 'Dolphin Tale 2'}
# {'M': 'Dolphin Tale'}
# {'M': 'Domestic Disturbance'}
# {'M': 'Don Jon'}
# {'M': 'Don Juan DeMarco'}
# {'M': 'Don McKay'}
# {'M': 'Donnie Brasco'}
# {'M': 'Donnie Darko'}
# {'M': 'Donovans Reef'}
# {'M': 'Dont Be Afraid of the Dark'}
# {'M': 'Dope'}
# {'M': 'Double Impact'}
# {'M': 'Double Take'}
# {'M': 'Doubt'}
# {'M': 'Dougs 1st Movie'}
# {'M': 'Down in the Valley'}
# {'M': 'Down to Earth'}
# {'M': 'Down to You'}
# {'M': 'Dr. Dolittle 2'}
# {'M': 'Dracula 2000'}
# {'M': 'Dracula Untold'}
# {'M': 'Dracula'}
# {'M': 'Draft Day'}
# {'M': 'Drag Me to Hell'}
# {'M': 'DragonHeart'}
# {'M': 'Dragonball Evolution'}
# {'M': 'Dream with the Fishes'}
# {'M': 'Dreamcatcher'}
# {'M': 'Dreamgirls'}
# {'M': 'Dressed to Kill'}
# {'M': 'Drillbit Taylor'}
# {'M': 'Drinking Buddies'}
# {'M': 'Drive Angry'}
# {'M': 'Drive Me Crazy'}
# {'M': 'Drive'}
# {'M': 'Driving Miss Daisy'}
# {'M': 'Drop Dead Gorgeous'}
# {'M': 'Drowning Mona'}
# {'M': 'Drumline'}
# {'M': 'Dry Spell'}
# {'M': 'Dude, Where’s My Car?'}
# {'M': 'Dudley Do-Right'}
# {'M': 'Due Date'}
# {'M': 'Duel in the Sun'}
# {'M': 'Duets'}
# {'M': 'Dumb and Dumber To'}
# {'M': 'Dumb and Dumber'}
# {'M': 'Dumb and Dumberer: When Harry Met Lloyd'}
# {'M': 'Dune'}
# {'M': 'Dwegons'}
# {'M': 'Dylan Dog: Dead of Night'}
# {'M': 'DysFunktional Family'}
# {'M': 'Dysfunctional Friends'}
# {'M': 'Déjà Vu'}
# {'M': 'E.T. the Extra-Terrestrial'}
# {'M': 'Eagle Eye'}
# {'M': 'Earth to Echo'}
# {'M': 'Easy A'}
# {'M': 'Eat Pray Love'}
# {'M': 'Echo Dr.'}
# {'M': 'Ed Wood'}
# {'M': 'Edmond'}
# {'M': 'Edtv'}
# {'M': 'Edward Scissorhands'}
# {'M': 'Eight Below'}
# {'M': 'Election'}
# {'M': 'Elf'}
# {'M': 'Elizabeth'}
# {'M': 'Elizabethtown'}
# {'M': 'Elmer Gantry'}
# {'M': 'Elsa & Fred'}
# {'M': 'Elysium'}
# {'M': 'Employee of the Month'}
# {'M': 'Enchanted'}
# {'M': 'End of Days'}
# {'M': 'End of Watch'}
# {'M': 'End of the Spear'}
# {'M': 'Enders Game'}
# {'M': 'Endless Love'}
# {'M': 'Enemy of the State'}
# {'M': 'Enough Said'}
# {'M': 'Enough'}
# {'M': 'Enter Nowhere'}
# {'M': 'Enter the Dangerous Mind'}
# {'M': 'Envy'}
# {'M': 'Epic Movie'}
# {'M': 'Epic'}
# {'M': 'Equilibrium'}
# {'M': 'Eraserhead'}
# {'M': 'Erin Brockovich'}
# {'M': 'Escape Plan'}
# {'M': 'Escape from Alcatraz'}
# {'M': 'Escape from L.A.'}
# {'M': 'Escape from New York'}
# {'M': 'Escape from Tomorrow'}
# {'M': 'Escape from the Planet of the Apes'}
# {'M': 'Eternal Sunshine of the Spotless Mind'}
# {'M': 'EuroTrip'}
# {'M': 'Evan Almighty'}
# {'M': 'Ever After: A Cinderella Story'}
# {'M': 'Everybodys Fine'}
# {'M': 'Everyone Says I Love You'}
# {'M': 'Everything Must Go'}
# {'M': 'Everything Put Together'}
# {'M': 'Everything You Always Wanted to Know About Sex *But Were Afraid to Ask'}
# {'M': 'Evil Dead II'}
# {'M': 'Evil Dead'}
# {'M': 'Evita'}
# {'M': 'Excessive Force'}
# {'M': 'Executive Decision'}
# {'M': 'Exorcist II: The Heretic'}
# {'M': 'Exorcist: The Beginning'}
# {'M': 'Extract'}
# {'M': 'Extraordinary Measures'}
# {'M': 'Extreme Measures'}
# {'M': 'Extreme Movie'}
# {'M': 'Extreme Ops'}
# {'M': 'Extremely Loud & Incredibly Close'}
# {'M': 'Eye for an Eye'}
# {'M': 'Eye of the Dolphin'}
# {'M': 'F.I.S.T.'}
# {'M': 'Face/Off'}
# {'M': 'Facing the Giants'}
# {'M': 'Factory Girl'}
# {'M': 'Fahrenheit 9/11'}
# {'M': 'Failure to Launch'}
# {'M': 'Fair Game'}
# {'M': 'Faithful'}
# {'M': 'Falcon Rising'}
# {'M': 'Fame'}
# {'M': 'Family Plot'}
# {'M': 'Fantasia 2000'}
# {'M': 'Fantasia'}
# {'M': 'Fantastic Four'}
# {'M': 'Fantastic Mr. Fox'}
# {'M': 'Far from Heaven'}
# {'M': 'Farce of the Penguins'}
# {'M': 'Fast Five'}
# {'M': 'Fast Times at Ridgemont High'}
# {'M': 'Faster'}
# {'M': 'Fat Albert'}
# {'M': 'Fat, Sick & Nearly Dead'}
# {'M': 'Fatal Attraction'}
# {'M': 'Fear Clinic'}
# {'M': 'Fear and Loathing in Las Vegas'}
# {'M': 'Feast'}
# {'M': 'Fiddler on the Roof'}
# {'M': 'Fifty Shades of Black'}
# {'M': 'Fifty Shades of Grey'}
# {'M': 'Fight Valley'}
# {'M': 'Fight to the Finish'}
# {'M': 'Final Destination 2'}
# {'M': 'Final Destination 5'}
# {'M': 'Final Destination'}
# {'M': 'Finding Forrester'}
# {'M': 'Finding Nemo'}
# {'M': 'Finishing The Game'}
# {'M': 'Firefox'}
# {'M': 'Fireproof'}
# {'M': 'Firestarter'}
# {'M': 'Firewall'}
# {'M': 'First Blood'}
# {'M': 'First Knight'}
# {'M': 'First Love, Last Rites'}
# {'M': 'Flags of Our Fathers'}
# {'M': 'Flash Gordon'}
# {'M': 'Flash of Genius'}
# {'M': 'Flashdance'}
# {'M': 'Flatliners'}
# {'M': 'Flawless'}
# {'M': 'Fled'}
# {'M': 'Flight of the Intruder'}
# {'M': 'Flight of the Phoenix'}
# {'M': 'Flight'}
# {'M': 'Flightplan'}
# {'M': 'Flipped'}
# {'M': 'Flipper'}
# {'M': 'Flirting with Disaster'}
# {'M': 'Flubber'}
# {'M': 'Flywheel'}
# {'M': 'Focus'}
# {'M': 'Food, Inc.'}
# {'M': 'Foodfight!'}
# {'M': 'Foolish'}
# {'M': 'Fools Gold'}
# {'M': 'Footloose'}
# {'M': 'For Colored Girls'}
# {'M': 'For Love of the Game'}
# {'M': 'For Your Consideration'}
# {'M': 'For a Good Time, Call...'}
# {'M': 'Forget Me Not'}
# {'M': 'Forgetting Sarah Marshall'}
# {'M': 'Forrest Gump'}
# {'M': 'Forty Shades of Blue'}
# {'M': 'Four Brothers'}
# {'M': 'Four Christmases'}
# {'M': 'Four Rooms'}
# {'M': 'Four Single Fathers'}
# {'M': 'Frankenweenie'}
# {'M': 'Frat Party'}
# {'M': 'Freakonomics'}
# {'M': 'Freaky Deaky'}
# {'M': 'Freaky Friday'}
# {'M': 'Freddy Got Fingered'}
# {'M': 'Freddys Dead: The Final Nightmare'}
# {'M': 'Free Birds'}
# {'M': 'Free State of Jones'}
# {'M': 'Freedom'}
# {'M': 'Freeheld'}
# {'M': 'Freeway'}
# {'M': 'Frequency'}
# {'M': 'Friday After Next'}
# {'M': 'Friday the 13th Part 2'}
# {'M': 'Friday the 13th Part III'}
# {'M': 'Friday the 13th Part VI: Jason Lives'}
# {'M': 'Friday the 13th Part VII: The New Blood'}
# {'M': 'Friday the 13th Part VIII: Jason Takes Manhattan'}
# {'M': 'Friday the 13th: A New Beginning'}
# {'M': 'Friday the 13th: The Final Chapter'}
# {'M': 'Friday'}
# {'M': 'Friends with Benefits'}
# {'M': 'Friends with Money'}
# {'M': 'From Dusk Till Dawn'}
# {'M': 'From Here to Eternity'}
# {'M': 'From Justin to Kelly'}
# {'M': 'From a Whisper to a Scream'}
# {'M': 'Frost/Nixon'}
# {'M': 'Frozen River'}
# {'M': 'Frozen'}
# {'M': 'Fruitvale Station'}
# {'M': 'Fuel'}
# {'M': 'Full Frontal'}
# {'M': 'Fun Size'}
# {'M': 'Fun with Dick and Jane'}
# {'M': 'Funny Ha Ha'}
# {'M': 'Funny People'}
# {'M': 'Fur: An Imaginary Portrait of Diane Arbus'}
# {'M': 'G-Force'}
# {'M': 'G.I. Jane'}
# {'M': 'G.I. Joe: Retaliation'}
# {'M': 'Galaxina'}
# {'M': 'Galaxy Quest'}
# {'M': 'Gamer'}
# {'M': 'Gangs of New York'}
# {'M': 'Gangster Squad'}
# {'M': 'Garden State'}
# {'M': 'Garfield'}
# {'M': 'Gattaca'}
# {'M': 'Gentlemans Agreement'}
# {'M': 'Gentlemen Broncos'}
# {'M': 'George Washington'}
# {'M': 'George of the Jungle'}
# {'M': 'Georgia Rule'}
# {'M': 'Gerry'}
# {'M': 'Get Carter'}
# {'M': 'Get Hard'}
# {'M': 'Get Him to the Greek'}
# {'M': 'Get Low'}
# {'M': 'Get Over It'}
# {'M': 'Get Rich or Die Tryin'}
# {'M': 'Get Shorty'}
# {'M': 'Get on Up'}
# {'M': 'Get on the Bus'}
# {'M': 'Gettysburg'}
# {'M': 'Ghost Dog: The Way of the Samurai'}
# {'M': 'Ghost Rider'}
# {'M': 'Ghost Town'}
# {'M': 'Ghost'}
# {'M': 'Ghostbusters'}
# {'M': 'Ghosts of Mars'}
# {'M': 'Ghosts of Mississippi'}
# {'M': 'Gigli'}
# {'M': 'Girl 6'}
# {'M': 'Girls Gone Dead'}
# {'M': 'Give Me Shelter'}
# {'M': 'Glee: The Concert Movie'}
# {'M': 'Glengarry Glen Ross'}
# {'M': 'Glitter'}
# {'M': 'Glory Road'}
# {'M': 'Glory'}
# {'M': 'Go for It!'}
# {'M': 'Go'}
# {'M': 'Gods Not Dead 2'}
# {'M': 'Gods and Generals'}
# {'M': 'Going the Distance'}
# {'M': 'Gone Girl'}
# {'M': 'Gone in Sixty Seconds'}
# {'M': 'Gone with the Wind'}
# {'M': 'Good Boy!'}
# {'M': 'Good Deeds'}
# {'M': 'Good Dick'}
# {'M': 'Good Intentions'}
# {'M': 'Good Kill'}
# {'M': 'Good Morning, Vietnam'}
# {'M': 'GoodFellas'}
# {'M': 'Gossip'}
# {'M': 'Gothika'}
# {'M': 'Grace Unplugged'}
# {'M': 'Gracie'}
# {'M': 'Graduation Day'}
# {'M': 'Gran Torino'}
# {'M': 'Grandmas Boy'}
# {'M': 'Grease'}
# {'M': 'Green Lantern'}
# {'M': 'Green Room'}
# {'M': 'Green Street Hooligans: Underground'}
# {'M': 'Gremlins 2: The New Batch'}
# {'M': 'Gremlins'}
# {'M': 'Gridiron Gang'}
# {'M': 'Grindhouse'}
# {'M': 'Groove'}
# {'M': 'Grosse Pointe Blank'}
# {'M': 'Groundhog Day'}
# {'M': 'Grown Ups 2'}
# {'M': 'Grown Ups'}
# {'M': 'Grudge Match'}
# {'M': 'Guess Who'}
# {'M': 'Gullivers Travels'}
# {'M': 'Gun Shy'}
# {'M': 'H.'}
# {'M': 'Hackers'}
# {'M': 'Hail, Caesar!'}
# {'M': 'Half Baked'}
# {'M': 'Half Nelson'}
# {'M': 'Hall Pass'}
# {'M': 'Halloween 4: The Return of Michael Myers'}
# {'M': 'Halloween 5: The Revenge of Michael Myers'}
# {'M': 'Halloween II'}
# {'M': 'Halloween III: Season of the Witch'}
# {'M': 'Halloween'}
# {'M': 'Halloween: Resurrection'}
# {'M': 'Halloween: The Curse of Michael Myers'}
# {'M': 'Hamlet 2'}
# {'M': 'Hancock'}
# {'M': 'Hang em High'}
# {'M': 'Hannah Montana: The Movie'}
# {'M': 'Hansel & Gretel: Witch Hunters'}
# {'M': 'Hansel and Gretel Get Baked'}
# {'M': 'Happiness'}
# {'M': 'Happy Christmas'}
# {'M': 'Happy Gilmore'}
# {'M': 'Happy, Texas'}
# {'M': 'Hard Candy'}
# {'M': 'Harley Davidson and the Marlboro Man'}
# {'M': 'Harold & Kumar Escape from Guantanamo Bay'}
# {'M': 'Harold & Kumar Go to White Castle'}
# {'M': 'Harper'}
# {'M': 'Harriet the Spy'}
# {'M': 'Harsh Times'}
# {'M': 'Harts War'}
# {'M': 'Harvard Man'}
# {'M': 'Hatchet'}
# {'M': 'Hav Plenty'}
# {'M': 'Hayride'}
# {'M': 'He Got Game'}
# {'M': 'Head Over Heels'}
# {'M': 'Head of State'}
# {'M': 'Heartbeeps'}
# {'M': 'Heartbreakers'}
# {'M': 'Heaven is for Real'}
# {'M': 'Heavens Gate'}
# {'M': 'Hedwig and the Angry Inch'}
# {'M': 'Heist'}
# {'M': 'Held Up'}
# {'M': 'Hellboy'}
# {'M': 'Hells Angels'}
# {'M': 'Henry & Me'}
# {'M': 'Herbie Fully Loaded'}
# {'M': 'Hercules'}
# {'M': 'Here Comes the Boom'}
# {'M': 'Here On Earth'}
# {'M': 'Hereafter'}
# {'M': 'Heroes of Dirt'}
# {'M': 'Hesher'}
# {'M': 'Hey Arnold! The Movie'}
# {'M': 'Hidalgo'}
# {'M': 'Hide and Seek'}
# {'M': 'High Anxiety'}
# {'M': 'High Crimes'}
# {'M': 'High Noon'}
# {'M': 'High Plains Drifter'}
# {'M': 'High Road'}
# {'M': 'High School Musical 2'}
# {'M': 'High School Musical 3: Senior Year'}
# {'M': 'High School Musical'}
# {'M': 'Higher Ground'}
# {'M': 'Highlander: Endgame'}
# {'M': 'Highway'}
# {'M': 'History of the World: Part I'}
# {'M': 'Hit & Run'}
# {'M': 'Hitch'}
# {'M': 'Hits'}
# {'M': 'Hobo with a Shotgun'}
# {'M': 'Hocus Pocus'}
# {'M': 'Hoffa'}
# {'M': 'Holes'}
# {'M': 'Hollywood Ending'}
# {'M': 'Hollywood Homicide'}
# {'M': 'Holy Man'}
# {'M': 'Home Alone 2: Lost in New York'}
# {'M': 'Home Alone'}
# {'M': 'Home Fries'}
# {'M': 'Home Run'}
# {'M': 'Home for the Holidays'}
# {'M': 'Home on the Range'}
# {'M': 'Home'}
# {'M': 'Homefront'}
# {'M': 'Honey'}
# {'M': 'Hoodwinked Too! Hood VS. Evil'}
# {'M': 'Hoodwinked!'}
# {'M': 'Hook'}
# {'M': 'Hoop Dreams'}
# {'M': 'Hoot'}
# {'M': 'Hope Floats'}
# {'M': 'Hope Springs'}
# {'M': 'Horrible Bosses 2'}
# {'M': 'Horrible Bosses'}
# {'M': 'Horse Camp'}
# {'M': 'Hostel'}
# {'M': 'Hostel: Part II'}
# {'M': 'Hot Pursuit'}
# {'M': 'Hot Rod'}
# {'M': 'Hot Tub Time Machine 2'}
# {'M': 'Hot Tub Time Machine'}
# {'M': 'Hotel Transylvania 2'}
# {'M': 'Hotel Transylvania'}
# {'M': 'Hotel for Dogs'}
# {'M': 'House Party 2'}
# {'M': 'House at the End of the Drive'}
# {'M': 'House at the End of the Street'}
# {'M': 'House of 1000 Corpses'}
# {'M': 'House of D'}
# {'M': 'House of Sand and Fog'}
# {'M': 'House of Wax'}
# {'M': 'House on Haunted Hill'}
# {'M': 'How Do You Know'}
# {'M': 'How Green Was My Valley'}
# {'M': 'How High'}
# {'M': 'How Stella Got Her Groove Back'}
# {'M': 'How to Be Single'}
# {'M': 'How to Deal'}
# {'M': 'How to Fall in Love'}
# {'M': 'How to Train Your Dragon 2'}
# {'M': 'How to Train Your Dragon'}
# {'M': 'Howard the Duck'}
# {'M': 'Hud'}
# {'M': 'Hudson Hawk'}
# {'M': 'Hulk'}
# {'M': 'Hurricane Streets'}
# {'M': 'Hustle & Flow'}
# {'M': 'I Am Legend'}
# {'M': 'I Am Number Four'}
# {'M': 'I Am Sam'}
# {'M': 'I Am Wrath'}
# {'M': 'I Can Do Bad All By Myself'}
# {'M': 'I Dont Know How She Does It'}
# {'M': 'I Dreamed of Africa'}
# {'M': 'I Got the Hook Up'}
# {'M': 'I Know What You Did Last Summer'}
# {'M': 'I Love You Phillip Morris'}
# {'M': 'I Love You, Dont Touch Me!'}
# {'M': 'I Love You, Man'}
# {'M': 'I Married a Strange Person!'}
# {'M': 'I Origins'}
# {'M': 'I Spit on Your Grave'}
# {'M': 'I Spy'}
# {'M': 'I Still Know What You Did Last Summer'}
# {'M': 'I Want Someone to Eat Cheese With'}
# {'M': 'I, Frankenstein'}
# {'M': 'I, Robot'}
# {'M': 'Ice Age'}
# {'M': 'Ice Age: Continental Drift'}
# {'M': 'Ice Age: Dawn of the Dinosaurs'}
# {'M': 'Ice Age: The Meltdown'}
# {'M': 'Ice Princess'}
# {'M': 'Identity Thief'}
# {'M': 'Identity'}
# {'M': 'Idiocracy'}
# {'M': 'Idle Hands'}
# {'M': 'Idlewild'}
# {'M': 'If I Stay'}
# {'M': 'Igby Goes Down'}
# {'M': 'Im Not There.'}
# {'M': 'Imagine That'}
# {'M': 'Immortals'}
# {'M': 'Impact Point'}
# {'M': 'Impostor'}
# {'M': 'In & Out'}
# {'M': 'In Cold Blood'}
# {'M': 'In Dreams'}
# {'M': 'In Good Company'}
# {'M': 'In Her Line of Fire'}
# {'M': 'In Time'}
# {'M': 'In Too Deep'}
# {'M': 'In the Bedroom'}
# {'M': 'In the Heart of the Sea'}
# {'M': 'In the Land of Blood and Honey'}
# {'M': 'In the Land of Women'}
# {'M': 'In the Valley of Elah'}
# {'M': 'Independence Day'}
# {'M': 'Independence Day: Resurgence'}
# {'M': 'Indiana Jones and the Kingdom of the Crystal Skull'}
# {'M': 'Indiana Jones and the Last Crusade'}
# {'M': 'Indiana Jones and the Temple of Doom'}
# {'M': 'Indignation'}
# {'M': 'Infamous'}
# {'M': 'Inherent Vice'}
# {'M': 'Ink'}
# {'M': 'Inside Deep Throat'}
# {'M': 'Inside Job'}
# {'M': 'Inside Llewyn Davis'}
# {'M': 'Inside Man'}
# {'M': 'Inside Out'}
# {'M': 'Insidious'}
# {'M': 'Insidious: Chapter 2'}
# {'M': 'Insomnia'}
# {'M': 'Inspector Gadget'}
# {'M': 'Instinct'}
# {'M': 'Insurgent'}
# {'M': 'Interview with the Vampire'}
# {'M': 'Into the Blue'}
# {'M': 'Into the Storm'}
# {'M': 'Into the Wild'}
# {'M': 'Into the Woods'}
# {'M': 'Intolerable Cruelty'}
# {'M': 'Intolerance'}
# {'M': 'Invaders from Mars'}
# {'M': 'Invasion U.S.A.'}
# {'M': 'Invictus'}
# {'M': 'Ira & Abby'}
# {'M': 'Iron Man 2'}
# {'M': 'Iron Man'}
# {'M': 'Ishtar'}
# {'M': 'Isnt She Great'}
# {'M': 'It Follows'}
# {'M': 'It Happened One Night'}
# {'M': 'Its Complicated'}
# {'M': 'Its Kind of a Funny Story'}
# {'M': 'Its a Mad, Mad, Mad, Mad World'}
# {'M': 'Its a Wonderful Life'}
# {'M': 'J. Edgar'}
# {'M': 'JFK'}
# {'M': 'Jack Reacher'}
# {'M': 'Jack and Jill'}
# {'M': 'Jack the Giant Slayer'}
# {'M': 'Jackass 3D'}
# {'M': 'Jackass Number Two'}
# {'M': 'Jackass: The Movie'}
# {'M': 'Jackie Brown'}
# {'M': 'Jade'}
# {'M': 'Jane Got a Gun'}
# {'M': 'Janky Promoters'}
# {'M': 'Jason Goes to Hell: The Final Friday'}
# {'M': 'Jason X'}
# {'M': 'Jawbreaker'}
# {'M': 'Jaws 2'}
# {'M': 'Jaws'}
# {'M': 'Jaws: The Revenge'}
# {'M': 'Jay and Silent Bob Strike Back'}
# {'M': 'Jeepers Creepers 2'}
# {'M': 'Jeff, Who Lives at Home'}
# {'M': 'Jefferson in Paris'}
# {'M': 'Jekyll and Hyde ... Together Again'}
# {'M': 'Jennifers Body'}
# {'M': 'Jerry Maguire'}
# {'M': 'Jersey Boys'}
# {'M': 'Jersey Girl'}
# {'M': 'Jimmy Neutron: Boy Genius'}
# {'M': 'Jimmy and Judy'}
# {'M': 'Jingle All the Way'}
# {'M': 'Joe Dirt'}
# {'M': 'Joe Somebody'}
# {'M': 'Joe'}
# {'M': 'John Carter'}
# {'M': 'John Q'}
# {'M': 'Johnson Family Vacation'}
# {'M': 'Jonah Hex'}
# {'M': 'Jonah: A VeggieTales Movie'}
# {'M': 'Journey 2: The Mysterious Island'}
# {'M': 'Journey to the Center of the Earth'}
# {'M': 'Joy Ride'}
# {'M': 'Joy'}
# {'M': 'Joyful Noise'}
# {'M': 'Julia'}
# {'M': 'Julie & Julia'}
# {'M': 'Jumping the Broom'}
# {'M': 'Juno'}
# {'M': 'Jupiter Ascending'}
# {'M': 'Jurassic Park III'}
# {'M': 'Jurassic Park'}
# {'M': 'Jurassic World'}
# {'M': 'Just Go with It'}
# {'M': 'Just Like Heaven'}
# {'M': 'Just Looking'}
# {'M': 'Just My Luck'}
# {'M': 'Just Wright'}
# {'M': 'Justin Bieber: Never Say Never'}
# {'M': 'Juwanna Mann'}
# {'M': 'Kansas City'}
# {'M': 'Kate & Leopold'}
# {'M': 'Katy Perry: Part of Me'}
# {'M': 'Keanu'}
# {'M': 'Keeping Up with the Steins'}
# {'M': 'Keeping the Faith'}
# {'M': 'Kevin Hart: Laugh at My Pain'}
# {'M': 'Kevin Hart: Let Me Explain'}
# {'M': 'Kick-Ass 2'}
# {'M': 'Kickboxer: Vengeance'}
# {'M': 'Kicking & Screaming'}
# {'M': 'Kicks'}
# {'M': 'Kill Bill: Vol. 1'}
# {'M': 'Kill Bill: Vol. 2'}
# {'M': 'Kill the Messenger'}
# {'M': 'Killer Joe'}
# {'M': 'Killers'}
# {'M': 'Killing Them Softly'}
# {'M': 'Kindergarten Cop'}
# {'M': 'Kingdom of the Spiders'}
# {'M': 'Kingpin'}
# {'M': 'Kiss Kiss Bang Bang'}
# {'M': 'Kiss of Death'}
# {'M': 'Kiss the Bride'}
# {'M': 'Kiss the Girls'}
# {'M': 'Kissing Jessica Stein'}
# {'M': 'Kit Kittredge: An American Girl'}
# {'M': 'Knight and Day'}
# {'M': 'Knockaround Guys'}
# {'M': 'Knocked Up'}
# {'M': 'Krampus'}
# {'M': 'Krush Groove'}
# {'M': 'Kundun'}
# {'M': 'Kung Fu Panda 2'}
# {'M': 'Kung Fu Panda'}
# {'M': 'L.A. Confidential'}
# {'M': 'L.I.E.'}
# {'M': 'LOL'}
# {'M': 'La Bamba'}
# {'M': 'Labor Day'}
# {'M': 'Ladder 49'}
# {'M': 'Lady in White'}
# {'M': 'Lady in the Water'}
# {'M': 'Ladyhawke'}
# {'M': 'Lake Placid'}
# {'M': 'Lakeview Terrace'}
# {'M': 'Land of the Lost'}
# {'M': 'Lara Croft Tomb Raider: The Cradle of Life'}
# {'M': 'Lara Croft: Tomb Raider'}
# {'M': 'Larry Crowne'}
# {'M': 'Larry the Cable Guy: Health Inspector'}
# {'M': 'Lars and the Real Girl'}
# {'M': 'Last Action Hero'}
# {'M': 'Last Holiday'}
# {'M': 'Last Vegas'}
# {'M': 'Latter Days'}
# {'M': 'Law Abiding Citizen'}
# {'M': 'Leaving Las Vegas'}
# {'M': 'Left Behind'}
# {'M': 'Legal Eagles'}
# {'M': 'Legally Blonde 2: Red, White & Blonde'}
# {'M': 'Legally Blonde'}
# {'M': 'Legends of the Fall'}
# {'M': 'Legion'}
# {'M': 'Lethal Weapon 3'}
# {'M': 'Lethal Weapon 4'}
# {'M': 'Lets Be Cops'}
# {'M': 'Lets Go to Prison'}
# {'M': 'Lets Kill Wards Wife'}
# {'M': 'Letters to God'}
# {'M': 'Letters to Juliet'}
# {'M': 'Liar Liar'}
# {'M': 'Life During Wartime'}
# {'M': 'Life as a House'}
# {'M': 'Life of Pi'}
# {'M': 'Light It Up'}
# {'M': 'Light Sleeper'}
# {'M': 'Lights Out'}
# {'M': 'Like Crazy'}
# {'M': 'Like Mike'}
# {'M': 'Lilo & Stitch'}
# {'M': 'Lions for Lambs'}
# {'M': 'Listening'}
# {'M': 'Little Big Top'}
# {'M': 'Little Black Book'}
# {'M': 'Little Children'}
# {'M': 'Little Fockers'}
# {'M': 'Little Man'}
# {'M': 'Little Miss Sunshine'}
# {'M': 'Little Nicky'}
# {'M': 'Little Shop of Horrors'}
# {'M': 'Little Women'}
# {'M': 'Living Out Loud'}
# {'M': 'Locker 13'}
# {'M': 'Logans Run'}
# {'M': 'Lone Star'}
# {'M': 'Lone Survivor'}
# {'M': 'Lone Wolf McQuade'}
# {'M': 'Loser'}
# {'M': 'Lost Souls'}
# {'M': 'Lost in Space'}
# {'M': 'Lottery Ticket'}
# {'M': 'Love & Basketball'}
# {'M': 'Love & Other Drugs'}
# {'M': 'Love Jones'}
# {'M': 'Love Letters'}
# {'M': 'Love Me Tender'}
# {'M': 'Love Ranch'}
# {'M': 'Love Stinks'}
# {'M': 'Love in the Time of Cholera'}
# {'M': 'Love in the Time of Monsters'}
# {'M': 'Love the Coopers'}
# {'M': 'Lovely & Amazing'}
# {'M': 'Loves Abiding Joy'}
# {'M': 'Loving Annabelle'}
# {'M': 'Lucky You'}
# {'M': 'MacGruber'}
# {'M': 'Machete Kills'}
# {'M': 'Machete'}
# {'M': 'Machine Gun Preacher'}
# {'M': 'Mad City'}
# {'M': 'Mad Hot Ballroom'}
# {'M': 'Mad Money'}
# {'M': 'Madagascar 3: Europes Most Wanted'}
# {'M': 'Madagascar'}
# {'M': 'Madagascar: Escape 2 Africa'}
# {'M': 'Made'}
# {'M': 'Madea Goes to Jail'}
# {'M': 'Madeas Family Reunion'}
# {'M': 'Madeas Witness Protection'}
# {'M': 'Madison'}
# {'M': 'Magic Mike XXL'}
# {'M': 'Magic Mike'}
# {'M': 'Magnolia'}
# {'M': 'Maid in Manhattan'}
# {'M': 'Major Dundee'}
# {'M': 'Major League'}
# {'M': 'Malcolm X'}
# {'M': 'Maleficent'}
# {'M': 'Malevolence'}
# {'M': 'Malibus Most Wanted'}
# {'M': 'Mallrats'}
# {'M': 'Malone'}
# {'M': 'Man of the House'}
# {'M': 'Man of the Year'}
# {'M': 'Man on a Ledge'}
# {'M': 'Man on the Moon'}
# {'M': 'Manito'}
# {'M': 'Marci X'}
# {'M': 'Margaret'}
# {'M': 'Margin Call'}
# {'M': 'Marley & Me'}
# {'M': 'Marmaduke'}
# {'M': 'Mars Attacks!'}
# {'M': 'Mars Needs Moms'}
# {'M': 'Martha Marcy May Marlene'}
# {'M': 'Martian Child'}
# {'M': 'Martin Lawrence Live: Runteldat'}
# {'M': 'Marvins Room'}
# {'M': 'Mary Poppins'}
# {'M': 'Mary Reilly'}
# {'M': 'Masked and Anonymous'}
# {'M': 'Master and Commander: The Far Side of the World'}
# {'M': 'Max Keebles Big Move'}
# {'M': 'Max Payne'}
# {'M': 'Max'}
# {'M': 'Maximum Risk'}
# {'M': 'May'}
# {'M': 'Maze Runner: The Scorch Trials'}
# {'M': 'McFarland, USA'}
# {'M': 'Me Before You'}
# {'M': 'Me and Orson Welles'}
# {'M': 'Me and You and Everyone We Know'}
# {'M': 'Me, Myself & Irene'}
# {'M': 'Mean Creek'}
# {'M': 'Mean Girls'}
# {'M': 'Mean Streets'}
# {'M': 'Medicine Man'}
# {'M': 'Meeks Cutoff'}
# {'M': 'Meet Dave'}
# {'M': 'Meet Joe Black'}
# {'M': 'Meet the Fockers'}
# {'M': 'Meet the Parents'}
# {'M': 'Meet the Spartans'}
# {'M': 'Megamind'}
# {'M': 'Megiddo: The Omega Code 2'}
# {'M': 'Memento'}
# {'M': 'Memoirs of a Geisha'}
# {'M': 'Men in Black 3'}
# {'M': 'Men in Black II'}
# {'M': 'Men in Black'}
# {'M': 'Men of Honor'}
# {'M': 'Men of War'}
# {'M': 'Menace II Society'}
# {'M': 'Mercury Rising'}
# {'M': 'Message in a Bottle'}
# {'M': 'Metallica: Through the Never'}
# {'M': 'Meteor'}
# {'M': 'Metropolitan'}
# {'M': 'Mi America'}
# {'M': 'Michael Clayton'}
# {'M': 'Michael Jordan to the Max'}
# {'M': 'Middle of Nowhere'}
# {'M': 'Midnight Cowboy'}
# {'M': 'Midnight Run'}
# {'M': 'Midnight Special'}
# {'M': 'Midnight in the Garden of Good and Evil'}
# {'M': 'Mighty Joe Young'}
# {'M': 'Milk'}
# {'M': 'Million Dollar Arm'}
# {'M': 'Million Dollar Baby'}
# {'M': 'Minions'}
# {'M': 'Minority Report'}
# {'M': 'Miracle'}
# {'M': 'Miracles from Heaven'}
# {'M': 'Mirror Mirror'}
# {'M': 'Misconduct'}
# {'M': 'Miss Congeniality 2: Armed and Fabulous'}
# {'M': 'Miss Congeniality'}
# {'M': 'Miss March'}
# {'M': 'Mission to Mars'}
# {'M': 'Mission: Impossible'}
# {'M': 'Mo Better Blues'}
# {'M': 'Moby Dick'}
# {'M': 'Modern Times'}
# {'M': 'Molly'}
# {'M': 'Mommie Dearest'}
# {'M': 'Moms Night Out'}
# {'M': 'Mona Lisa Smile'}
# {'M': 'Money Monster'}
# {'M': 'Money Talks'}
# {'M': 'Money Train'}
# {'M': 'Moneyball'}
# {'M': 'Monkeybone'}
# {'M': 'Monster House'}
# {'M': 'Monster'}
# {'M': 'Monster-in-Law'}
# {'M': 'Monsters Ball'}
# {'M': 'Monsters University'}
# {'M': 'Monsters vs Aliens'}
# {'M': 'Monsters, Inc.'}
# {'M': 'Moonlight Mile'}
# {'M': 'Moonrise Kingdom'}
# {'M': 'Mooz-lum'}
# {'M': 'Morning Glory'}
# {'M': 'Mortal Kombat'}
# {'M': 'Mortal Kombat: Annihilation'}
# {'M': 'Mortdecai'}
# {'M': 'Motherhood'}
# {'M': 'Movie 43'}
# {'M': 'Mr. & Mrs. Smith'}
# {'M': 'Mr. 3000'}
# {'M': 'Mr. Church'}
# {'M': 'Mr. Deeds'}
# {'M': 'Mr. Hollands Opus'}
# {'M': 'Mr. Peabody & Sherman'}
# {'M': 'Mr. Poppers Penguins'}
# {'M': 'Mr. Smith Goes to Washington'}
# {'M': 'Mrs. Doubtfire'}
# {'M': 'Mrs. Winterbourne'}
# {'M': 'Mud'}
# {'M': 'Mulan'}
# {'M': 'Multiplicity'}
# {'M': 'Mumford'}
# {'M': 'Muppets Most Wanted'}
# {'M': 'Muppets from Space'}
# {'M': 'Murder by Numbers'}
# {'M': 'Murderball'}
# {'M': 'Music and Lyrics'}
# {'M': 'Must Love Dogs'}
# {'M': 'My All American'}
# {'M': 'My Babys Daddy'}
# {'M': 'My Best Friends Girl'}
# {'M': 'My Best Friends Wedding'}
# {'M': 'My Big Fat Independent Movie'}
# {'M': 'My Bloody Valentine'}
# {'M': 'My Bosss Daughter'}
# {'M': 'My Cousin Vinny'}
# {'M': 'My Date with Drew'}
# {'M': 'My Dog Skip'}
# {'M': 'My Dog Tulip'}
# {'M': 'My Fair Lady'}
# {'M': 'My Favorite Martian'}
# {'M': 'My Fellow Americans'}
# {'M': 'My Girl'}
# {'M': 'My Last Day Without You'}
# {'M': 'My Name Is Bruce'}
# {'M': 'My Own Private Idaho'}
# {'M': 'My Sisters Keeper'}
# {'M': 'My Soul to Take'}
# {'M': 'My Stepmother is an Alien'}
# {'M': 'My Summer of Love'}
# {'M': 'My Super Ex-Girlfriend'}
# {'M': 'Mystery Men'}
# {'M': 'Mystic Pizza'}
# {'M': 'Mystic River'}
# {'M': 'Nacho Libre'}
# {'M': 'Nancy Drew'}
# {'M': 'Nanny McPhee and the Big Bang'}
# {'M': 'Napoleon Dynamite'}
# {'M': 'National Lampoons Loaded Weapon 1'}
# {'M': 'National Lampoons Vacation'}
# {'M': 'National Lampoon’s Van Wilder'}
# {'M': 'National Treasure'}
# {'M': 'Naturally Native'}
# {'M': 'Navy Seals vs. Zombies'}
# {'M': 'Nebraska'}
# {'M': 'Neighbors 2: Sorority Rising'}
# {'M': 'Neighbors'}
# {'M': 'Nerve'}
# {'M': 'Network'}
# {'M': 'Never Back Down 2: The Beatdown'}
# {'M': 'Never Back Down'}
# {'M': 'New Nightmare'}
# {'M': 'New Years Eve'}
# {'M': 'New York Minute'}
# {'M': 'New York Stories'}
# {'M': 'New York, New York'}
# {'M': 'Next Day Air'}
# {'M': 'Next Friday'}
# {'M': 'Next Stop Wonderland'}
# {'M': 'Niagara'}
# {'M': 'Nick and Norahs Infinite Playlist'}
# {'M': 'Night at the Museum'}
# {'M': 'Night at the Museum: Battle of the Smithsonian'}
# {'M': 'Night of the Living Dead'}
# {'M': 'Nightcrawler'}
# {'M': 'Nighthawks'}
# {'M': 'Nims Island'}
# {'M': 'Nine 1/2 Weeks'}
# {'M': 'Nine Dead'}
# {'M': 'Nixon'}
# {'M': 'No Country for Old Men'}
# {'M': 'No Escape'}
# {'M': 'No Good Deed'}
# {'M': 'No Mans Land: The Rise of Reeker'}
# {'M': 'No Strings Attached'}
# {'M': 'Noah'}
# {'M': 'North Country'}
# {'M': 'Northfork'}
# {'M': 'Not Another Teen Movie'}
# {'M': 'Not Cool'}
# {'M': 'Not Easily Broken'}
# {'M': 'Nothing But a Man'}
# {'M': 'Nothing to Lose'}
# {'M': 'November'}
# {'M': 'Novocaine'}
# {'M': 'Now You See Me'}
# {'M': 'Nowhere to Run'}
# {'M': 'Nurse 3-D'}
# {'M': 'Nutty Professor II: The Klumps'}
# {'M': 'O'}
# {'M': 'Oblivion'}
# {'M': 'Observe and Report'}
# {'M': 'Obvious Child'}
# {'M': 'Oceans Eleven'}
# {'M': 'Oceans Thirteen'}
# {'M': 'Oceans Twelve'}
# {'M': 'October Baby'}
# {'M': 'Oculus'}
# {'M': 'Office Space'}
# {'M': 'Old Dogs'}
# {'M': 'Old Joy'}
# {'M': 'Old School'}
# {'M': 'Olympus Has Fallen'}
# {'M': 'On Deadly Ground'}
# {'M': 'On The Downlow'}
# {'M': 'On the Line'}
# {'M': 'On the Outs'}
# {'M': 'On the Waterfront'}
# {'M': 'Once Upon a Time in America'}
# {'M': 'Once Upon a Time in Mexico'}
# {'M': 'One Direction: This Is Us'}
# {'M': 'One Flew Over the Cuckoos Nest'}
# {'M': 'One Hour Photo'}
# {'M': 'One Mans Hero'}
# {'M': 'One Night with the King'}
# {'M': 'One True Thing'}
# {'M': 'One for the Money'}
# {'M': 'Only the Strong'}
# {'M': 'Open Range'}
# {'M': 'Open Season'}
# {'M': 'Open Secret'}
# {'M': 'Open Water'}
# {'M': 'Ordinary People'}
# {'M': 'Osmosis Jones'}
# {'M': 'Our Brand Is Crisis'}
# {'M': 'Our Family Wedding'}
# {'M': 'Our Idiot Brother'}
# {'M': 'Out Cold'}
# {'M': 'Out of Africa'}
# {'M': 'Out of Sight'}
# {'M': 'Out of Time'}
# {'M': 'Out of the Furnace'}
# {'M': 'Outbreak'}
# {'M': 'Outside Providence'}
# {'M': 'Over Her Dead Body'}
# {'M': 'Over the Hedge'}
# {'M': 'Oz: The Great and Powerful'}
# {'M': 'P.S. I Love You'}
# {'M': 'PCU'}
# {'M': 'Pacific Rim'}
# {'M': 'Pain & Gain'}
# {'M': 'Paint Your Wagon'}
# {'M': 'Pale Rider'}
# {'M': 'Palo Alto'}
# {'M': 'Pan'}
# {'M': 'Panic Room'}
# {'M': 'Paparazzi'}
# {'M': 'Paper Towns'}
# {'M': 'ParaNorman'}
# {'M': 'Paranormal Activity 2'}
# {'M': 'Paranormal Activity 3'}
# {'M': 'Paranormal Activity 4'}
# {'M': 'Paranormal Activity'}
# {'M': 'Paranormal Activity: The Marked Ones'}
# {'M': 'Parental Guidance'}
# {'M': 'Parker'}
# {'M': 'Pat Garrett & Billy the Kid'}
# {'M': 'Patch Adams'}
# {'M': 'Pathology'}
# {'M': 'Patriot Games'}
# {'M': 'Patton'}
# {'M': 'Paul Blart: Mall Cop 2'}
# {'M': 'Paul Blart: Mall Cop'}
# {'M': 'Paul'}
# {'M': 'Pay It Forward'}
# {'M': 'Payback'}
# {'M': 'Peace, Propaganda & the Promised Land'}
# {'M': 'Pearl Harbor'}
# {'M': 'Peeples'}
# {'M': 'Peggy Sue Got Married'}
# {'M': 'Penguins of Madagascar'}
# {'M': 'Percy Jackson: Sea of Monsters'}
# {'M': 'Pet Sematary'}
# {'M': 'Petes Dragon'}
# {'M': 'Phantasm II'}
# {'M': 'Phat Girlz'}
# {'M': 'Phenomenon'}
# {'M': 'Philadelphia'}
# {'M': 'Phone Booth'}
# {'M': 'Pi'}
# {'M': 'Pieces of April'}
# {'M': 'Pineapple Express'}
# {'M': 'Pink Flamingos'}
# {'M': 'Pink Narcissus'}
# {'M': 'Pink Ribbons, Inc.'}
# {'M': 'Pinocchio'}
# {'M': 'Piranha 3D'}
# {'M': 'Pirates of the Caribbean: At Worlds End'}
# {'M': 'Pirates of the Caribbean: On Stranger Tides'}
# {'M': 'Pirates of the Caribbean: The Curse of the Black Pearl'}
# {'M': 'Pitch Black'}
# {'M': 'Pitch Perfect 2'}
# {'M': 'Pitch Perfect'}
# {'M': 'Pixels'}
# {'M': 'Planet of the Apes'}
# {'M': 'Play It to the Bone'}
# {'M': 'Playing for Keeps'}
# {'M': 'Please Give'}
# {'M': 'Plush'}
# {'M': 'Pocahontas'}
# {'M': 'Pocketful of Miracles'}
# {'M': 'Poetic Justice'}
# {'M': 'Point Blank'}
# {'M': 'Police Academy'}
# {'M': 'Police Academy: Mission to Moscow'}
# {'M': 'Pollock'}
# {'M': 'Poltergeist III'}
# {'M': 'Poltergeist'}
# {'M': 'Poohs Heffalump Movie'}
# {'M': 'Poolhall Junkies'}
# {'M': 'Pootie Tang'}
# {'M': 'Porkys'}
# {'M': 'Poseidon'}
# {'M': 'Post Grad'}
# {'M': 'Poultrygeist: Night of the Chicken Dead'}
# {'M': 'Practical Magic'}
# {'M': 'Precious'}
# {'M': 'Predator 2'}
# {'M': 'Predator'}
# {'M': 'Predators'}
# {'M': 'Prefontaine'}
# {'M': 'Premium Rush'}
# {'M': 'Premonition'}
# {'M': 'Pretty Woman'}
# {'M': 'Pride and Glory'}
# {'M': 'Pride and Prejudice and Zombies'}
# {'M': 'Priest'}
# {'M': 'Primer'}
# {'M': 'Prince of Persia: The Sands of Time'}
# {'M': 'Princess Kaiulani'}
# {'M': 'Prison'}
# {'M': 'Prisoners'}
# {'M': 'Private Benjamin'}
# {'M': 'Project Almanac'}
# {'M': 'Project X'}
# {'M': 'Prom Night'}
# {'M': 'Prom'}
# {'M': 'Proof of Life'}
# {'M': 'Prophecy'}
# {'M': 'Psycho'}
# {'M': 'Public Enemies'}
# {'M': 'Pulp Fiction'}
# {'M': 'Pulse'}
# {'M': 'Punch-Drunk Love'}
# {'M': 'Puss in Boots'}
# {'M': 'Quarantine'}
# {'M': 'Queen Crab'}
# {'M': 'Quest for Camelot'}
# {'M': 'Quinceañera'}
# {'M': 'Quo Vadis'}
# {'M': 'R.I.P.D.'}
# {'M': 'R.L. Stines Monsterville: The Cabinet of Souls'}
# {'M': 'RED'}
# {'M': 'Rabbit Hole'}
# {'M': 'Race to Witch Mountain'}
# {'M': 'Rachel Getting Married'}
# {'M': 'Racing Stripes'}
# {'M': 'Radio Days'}
# {'M': 'Radio Flyer'}
# {'M': 'Radio'}
# {'M': 'Raging Bull'}
# {'M': 'Raiders of the Lost Ark'}
# {'M': 'Rain Man'}
# {'M': 'Raise Your Voice'}
# {'M': 'Raising Cain'}
# {'M': 'Raising Helen'}
# {'M': 'Raising Victor Vargas'}
# {'M': 'Rambo III'}
# {'M': 'Rambo: First Blood Part II'}
# {'M': 'Ramona and Beezus'}
# {'M': 'Random Hearts'}
# {'M': 'Rango'}
# {'M': 'Ransom'}
# {'M': 'Rapa Nui'}
# {'M': 'Ratatouille'}
# {'M': 'Ray'}
# {'M': 'Re-Kill'}
# {'M': 'Ready to Rumble'}
# {'M': 'Reality Show'}
# {'M': 'Rebecca'}
# {'M': 'Recess: Schools Out'}
# {'M': 'Red Dawn'}
# {'M': 'Red Eye'}
# {'M': 'Red River'}
# {'M': 'Red State'}
# {'M': 'Red Tails'}
# {'M': 'Redacted'}
# {'M': 'Redbelt'}
# {'M': 'Reds'}
# {'M': 'Reign Over Me'}
# {'M': 'Reindeer Games'}
# {'M': 'Religulous'}
# {'M': 'Remember Me'}
# {'M': 'Remember the Titans'}
# {'M': 'Rendition'}
# {'M': 'Reno 911!: Miami'}
# {'M': 'Rent'}
# {'M': 'Repo Man'}
# {'M': 'Repo! The Genetic Opera'}
# {'M': 'Requiem for a Dream'}
# {'M': 'Rescue Dawn'}
# {'M': 'Reservoir Dogs'}
# {'M': 'Resurrecting the Champ'}
# {'M': 'Return of the Jedi'}
# {'M': 'Return of the Living Dead 3'}
# {'M': 'Return to Me'}
# {'M': 'Riddick'}
# {'M': 'Ride Along 2'}
# {'M': 'Ride Along'}
# {'M': 'Ride with the Devil'}
# {'M': 'Riding in Cars with Boys'}
# {'M': 'Righteous Kill'}
# {'M': 'Rio 2'}
# {'M': 'Rio'}
# {'M': 'Rise of the Guardians'}
# {'M': 'Rise of the Planet of the Apes'}
# {'M': 'Risen'}
# {'M': 'Rivers Edge'}
# {'M': 'Rize'}
# {'M': 'Ri¢hie Ri¢h'}
# {'M': 'Road Hard'}
# {'M': 'Road House'}
# {'M': 'Road Trip'}
# {'M': 'Road to Perdition'}
# {'M': 'Roar'}
# {'M': 'Robin Hood: Prince of Thieves'}
# {'M': 'RoboCop 3'}
# {'M': 'Robot & Frank'}
# {'M': 'Robots'}
# {'M': 'Rock Star'}
# {'M': 'Rock of Ages'}
# {'M': 'Rockaway'}
# {'M': 'Rocky Balboa'}
# {'M': 'Rocky'}
# {'M': 'Rodeo Girl'}
# {'M': 'Roger & Me'}
# {'M': 'Role Models'}
# {'M': 'Roll Bounce'}
# {'M': 'Romance & Cigarettes'}
# {'M': 'Romeo + Juliet'}
# {'M': 'Romeo Must Die'}
# {'M': 'Rosemarys Baby'}
# {'M': 'Rosewater'}
# {'M': 'Rotor DR1'}
# {'M': 'Rounders'}
# {'M': 'Ruby in Paradise'}
# {'M': 'Rudderless'}
# {'M': 'Rugrats Go Wild'}
# {'M': 'Run All Night'}
# {'M': 'Run, Hide, Die'}
# {'M': 'Runaway Bride'}
# {'M': 'Runner Runner'}
# {'M': 'Running Forever'}
# {'M': 'Running with Scissors'}
# {'M': 'Rush Hour 2'}
# {'M': 'Rush Hour 3'}
# {'M': 'Rushmore'}
# {'M': 'S.W.A.T.'}
# {'M': 'Sabotage'}
# {'M': 'Safe Haven'}
# {'M': 'Safe House'}
# {'M': 'Safe Men'}
# {'M': 'Safe'}
# {'M': 'Safety Not Guaranteed'}
# {'M': 'Saint John of Las Vegas'}
# {'M': 'Saints and Soldiers'}
# {'M': 'Salt'}
# {'M': 'Salton Sea'}
# {'M': 'Salvation Boulevard'}
# {'M': 'Samsara'}
# {'M': 'Sanctuary: Quite a Conundrum'}
# {'M': 'Sanctum'}
# {'M': 'Sands of Iwo Jima'}
# {'M': 'Savage Grace'}
# {'M': 'Savages'}
# {'M': 'Save the Last Dance'}
# {'M': 'Saved!'}
# {'M': 'Saving Face'}
# {'M': 'Saving Private Ryan'}
# {'M': 'Saving Silverman'}
# {'M': 'Saw II'}
# {'M': 'Saw III'}
# {'M': 'Saw IV'}
# {'M': 'Saw V'}
# {'M': 'Saw'}
# {'M': 'Say It Isnt So'}
# {'M': 'Scarface'}
# {'M': 'Scary Movie 3'}
# {'M': 'Scary Movie 4'}
# {'M': 'Scary Movie 5'}
# {'M': 'Schindlers List'}
# {'M': 'School Daze'}
# {'M': 'School for Scoundrels'}
# {'M': 'Scooby-Doo 2: Monsters Unleashed'}
# {'M': 'Scooby-Doo'}
# {'M': 'Scott Pilgrim vs. the World'}
# {'M': 'Scream 2'}
# ...
# {'M': 'The Internship'}
# {'M': 'The Interview'}
# {'M': 'The Invasion'}
# {'M': 'The Invention of Lying'}
# {'M': 'The Iron Giant'}
# {'M': 'The Island of Dr. Moreau'}
# {'M': 'The Island'}
# {'M': 'The Jackal'}
# {'M': 'The Jerky Boys'}
# {'M': 'The Jimmy Show'}
# {'M': 'The Joneses'}
# {'M': 'The Judge'}
# {'M': 'The Juror'}
# {'M': 'The Karate Kid'}
# {'M': 'The Kentucky Fried Movie'}
# {'M': 'The Kid'}
# {'M': 'The Kids Are All Right'}
# {'M': 'The Killer Inside Me'}
# {'M': 'The Ladies Man'}
# {'M': 'The Lady from Shanghai'}
# {'M': 'The Ladykillers'}
# {'M': 'The Lake House'}
# {'M': 'The Last Airbender'}
# {'M': 'The Last Big Thing'}
# {'M': 'The Last Castle'}
# {'M': 'The Last Dragon'}
# {'M': 'The Last Exorcism Part II'}
# {'M': 'The Last Exorcism'}
# {'M': 'The Last Five Years'}
# {'M': 'The Last House on the Left'}
# {'M': 'The Last Shot'}
# {'M': 'The Last Sin Eater'}
# {'M': 'The Last Song'}
# {'M': 'The Last Stand'}
# {'M': 'The Last Temptation of Christ'}
# {'M': 'The Last Time I Committed Suicide'}
# {'M': 'The Last Waltz'}
# {'M': 'The Last Witch Hunter'}
# {'M': 'The Last of the Mohicans'}
# {'M': 'The Lazarus Effect'}
# {'M': 'The Legend of Bagger Vance'}
# {'M': 'The Legend of Hells Gate: An American Conspiracy'}
# {'M': 'The Legend of Hercules'}
# {'M': 'The Legend of the Lone Ranger'}
# {'M': 'The Lego Movie'}
# {'M': 'The Life Aquatic with Steve Zissou'}
# {'M': 'The Life Before Her Eyes'}
# {'M': 'The Limey'}
# {'M': 'The Lincoln Lawyer'}
# {'M': 'The Lion King'}
# {'M': 'The Lion of Judah'}
# {'M': 'The Lizzie McGuire Movie'}
# {'M': 'The Lone Ranger'}
# {'M': 'The Long Kiss Goodnight'}
# {'M': 'The Long Riders'}
# {'M': 'The Longest Day'}
# {'M': 'The Longest Ride'}
# {'M': 'The Longest Yard'}
# {'M': 'The Longshots'}
# {'M': 'The Losers'}
# {'M': 'The Lost Boys'}
# {'M': 'The Lost City'}
# {'M': 'The Lost Medallion: The Adventures of Billy Stone'}
# {'M': 'The Lost Skeleton of Cadavra'}
# {'M': 'The Lost Weekend'}
# {'M': 'The Lost World: Jurassic Park'}
# {'M': 'The Love Guru'}
# {'M': 'The Lucky One'}
# {'M': 'The Lucky Ones'}
# {'M': 'The Machinist'}
# {'M': 'The Maids Room'}
# {'M': 'The Majestic'}
# {'M': 'The Man Who Knew Too Little'}
# {'M': 'The Man Who Shot Liberty Valance'}
# {'M': 'The Man from Earth'}
# {'M': 'The Man from U.N.C.L.E.'}
# {'M': 'The Man'}
# {'M': 'The Manchurian Candidate'}
# {'M': 'The Marine'}
# {'M': 'The Martian'}
# {'M': 'The Mask of Zorro'}
# {'M': 'The Mask'}
# {'M': 'The Masked Saint'}
# {'M': 'The Master of Disguise'}
# {'M': 'The Master'}
# {'M': 'The Matrix Revolutions'}
# {'M': 'The Maze Runner'}
# {'M': 'The Mechanic'}
# {'M': 'The Messenger'}
# {'M': 'The Midnight Meat Train'}
# {'M': 'The Mighty Ducks'}
# {'M': 'The Mighty Macs'}
# {'M': 'The Mighty'}
# {'M': 'The Mirror Has Two Faces'}
# {'M': 'The Misfits'}
# {'M': 'The Missing Person'}
# {'M': 'The Mist'}
# {'M': 'The Molly Maguires'}
# {'M': 'The Mortal Instruments: City of Bones'}
# {'M': 'The Motel'}
# {'M': 'The Mothman Prophecies'}
# {'M': 'The Mudge Boy'}
# {'M': 'The Mummy Returns'}
# {'M': 'The Muppet Christmas Carol'}
# {'M': 'The Muppet Movie'}
# {'M': 'The Muppets'}
# {'M': 'The Muse'}
# {'M': 'The Naked Gun 2½: The Smell of Fear'}
# {'M': 'The Naked Gun 33⅓: The Final Insult'}
# {'M': 'The Nativity Story'}
# {'M': 'The Net'}
# {'M': 'The New Guy'}
# {'M': 'The New World'}
# {'M': 'The Newton Boys'}
# {'M': 'The Next Best Thing'}
# {'M': 'The Next Three Days'}
# {'M': 'The Night Listener'}
# {'M': 'The Notebook'}
# {'M': 'The Nuns Story'}
# {'M': 'The Nutcracker'}
# {'M': 'The Nutty Professor'}
# {'M': 'The Object of My Affection'}
# {'M': 'The Odd Life of Timothy Green'}
# {'M': 'The Oh in Ohio'}
# {'M': 'The One'}
# {'M': 'The Oogieloves in the Big Balloon Adventure'}
# {'M': 'The Opposite Sex'}
# {'M': 'The Original Kings of Comedy'}
# {'M': 'The Other Guys'}
# {'M': 'The Other Side of Heaven'}
# {'M': 'The Other Woman'}
# {'M': 'The Out-of-Towners'}
# {'M': 'The Outsiders'}
# {'M': 'The Pallbearer'}
# {'M': 'The Passion of the Christ'}
# {'M': 'The Past Is a Grotesque Animal'}
# {'M': 'The Peacemaker'}
# {'M': 'The Peanuts Movie'}
# {'M': 'The Pelican Brief'}
# {'M': 'The Perez Family'}
# {'M': 'The Perfect Game'}
# {'M': 'The Perfect Host'}
# {'M': 'The Perfect Man'}
# {'M': 'The Perfect Match'}
# {'M': 'The Perfect Storm'}
# {'M': 'The Perks of Being a Wallflower'}
# {'M': 'The Pink Panther'}
# {'M': 'The Pirate'}
# {'M': 'The Place Beyond the Pines'}
# {'M': 'The Players Club'}
# {'M': 'The Pledge'}
# {'M': 'The Poker House'}
# {'M': 'The Polar Express'}
# {'M': 'The Possession'}
# {'M': 'The Postman'}
# {'M': 'The Prestige'}
# {'M': 'The Prince of Egypt'}
# {'M': 'The Prince of Tides'}
# {'M': 'The Prince'}
# {'M': 'The Princess Bride'}
# {'M': 'The Princess Diaries 2: Royal Engagement'}
# {'M': 'The Princess Diaries'}
# {'M': 'The Princess and the Frog'}
# {'M': 'The Prisoner of Zenda'}
# {'M': 'The Producers'}
# {'M': 'The Prophecy'}
# {'M': 'The Proposal'}
# {'M': 'The Pursuit of D.B. Cooper'}
# {'M': 'The Pursuit of Happyness'}
# {'M': 'The Quiet American'}
# {'M': 'The Quiet'}
# {'M': 'The R.M.'}
# {'M': 'The Rage: Carrie 2'}
# {'M': 'The Rainmaker'}
# {'M': 'The Real Cancun'}
# {'M': 'The Reaping'}
# {'M': 'The Replacement Killers'}
# {'M': 'The Replacements'}
# {'M': 'The Return of the Living Dead'}
# {'M': 'The Ridiculous 6'}
# {'M': 'The Right Stuff'}
# {'M': 'The Ring Two'}
# {'M': 'The Rite'}
# {'M': 'The River Wild'}
# {'M': 'The Road to El Dorado'}
# {'M': 'The Road'}
# {'M': 'The Robe'}
# {'M': 'The Rock'}
# {'M': 'The Rocker'}
# {'M': 'The Rookie'}
# {'M': 'The Roommate'}
# {'M': 'The Rose'}
# {'M': 'The Royal Tenenbaums'}
# {'M': 'The Rugrats Movie'}
# {'M': 'The Ruins'}
# {'M': 'The Runaways'}
# {'M': 'The Rundown'}
# {'M': 'The Running Man'}
# {'M': 'The Saint'}
# {'M': 'The Santa Clause 2'}
# {'M': 'The Santa Clause'}
# {'M': 'The Savages'}
# {'M': 'The Scarlet Letter'}
# {'M': 'The Scorpion King'}
# {'M': 'The Secret Life of Bees'}
# {'M': 'The Secret Life of Pets'}
# {'M': 'The Secret Life of Walter Mitty'}
# {'M': 'The Sentinel'}
# {'M': 'The Sessions'}
# {'M': 'The Shadow'}
# {'M': 'The Shaggy Dog'}
# {'M': 'The Shallows'}
# {'M': 'The Shawshank Redemption'}
# {'M': 'The Shining'}
# {'M': 'The Shipping News'}
# {'M': 'The Siege'}
# {'M': 'The Signal'}
# {'M': 'The Silence of the Lambs'}
# {'M': 'The Simpsons Movie'}
# {'M': 'The Singing Detective'}
# {'M': 'The Singles Ward'}
# {'M': 'The Sisterhood of the Traveling Pants 2'}
# {'M': 'The Sisterhood of the Traveling Pants'}
# {'M': 'The Sitter'}
# {'M': 'The Sixth Sense'}
# {'M': 'The Skeleton Twins'}
# {'M': 'The Slaughter Rule'}
# {'M': 'The Smurfs 2'}
# {'M': 'The Smurfs'}
# {'M': 'The Social Network'}
# {'M': 'The Soloist'}
# {'M': 'The Son of No One'}
# {'M': 'The Sorcerers Apprentice'}
# {'M': 'The Sound and the Shadow'}
# {'M': 'The Sound of Music'}
# {'M': 'The Spanish Prisoner'}
# {'M': 'The Specials'}
# {'M': 'The Spectacular Now'}
# {'M': 'The Spiderwick Chronicles'}
# {'M': 'The Spirit'}
# {'M': 'The SpongeBob Movie: Sponge Out of Water'}
# {'M': 'The SpongeBob SquarePants Movie'}
# {'M': 'The Spy Next Door'}
# {'M': 'The Squid and the Whale'}
# {'M': 'The Station Agent'}
# {'M': 'The Stepfather'}
# {'M': 'The Stepford Wives'}
# {'M': 'The Sting'}
# {'M': 'The Story of Us'}
# {'M': 'The Straight Story'}
# {'M': 'The Sum of All Fears'}
# {'M': 'The Sweetest Thing'}
# {'M': 'The Switch'}
# {'M': 'The Taking of Pelham 1 2 3'}
# {'M': 'The Talented Mr. Ripley'}
# {'M': 'The Tempest'}
# {'M': 'The Ten'}
# {'M': 'The Terminal'}
# {'M': 'The Texas Chain Saw Massacre'}
# {'M': 'The Texas Chainsaw Massacre 2'}
# {'M': 'The Texas Chainsaw Massacre: The Beginning'}
# {'M': 'The Thing'}
# {'M': 'The Thirteenth Floor'}
# {'M': 'The Thomas Crown Affair'}
# {'M': 'The Three Burials of Melquiades Estrada'}
# {'M': 'The Three Musketeers'}
# {'M': 'The Three Stooges'}
# {'M': 'The Tigger Movie'}
# {'M': 'The Timber'}
# {'M': 'The Time Machine'}
# {'M': 'The Time Travelers Wife'}
# {'M': 'The To Do List'}
# {'M': 'The Town'}
# {'M': 'The Toxic Avenger Part II'}
# {'M': 'The Toxic Avenger'}
# {'M': 'The Transporter'}
# {'M': 'The Tree of Life'}
# {'M': 'The Trials Of Darryl Hunt'}
# {'M': 'The Trouble with Harry'}
# {'M': 'The Truman Show'}
# {'M': 'The Tuxedo'}
# {'M': 'The Twilight Saga: Breaking Dawn - Part 2'}
# {'M': 'The Twilight Saga: Eclipse'}
# {'M': 'The Twilight Saga: New Moon'}
# {'M': 'The Ugly Truth'}
# {'M': 'The Ultimate Gift'}
# {'M': 'The Unborn'}
# {'M': 'The Untouchables'}
# {'M': 'The Upside of Anger'}
# {'M': 'The Usual Suspects'}
# {'M': 'The Valley of Decision'}
# {'M': 'The Vatican Tapes'}
# {'M': 'The Veil'}
# {'M': 'The Velocity of Gary'}
# {'M': 'The Verdict'}
# {'M': 'The Village'}
# {'M': 'The Virgin Suicides'}
# {'M': 'The Virginity Hit'}
# {'M': 'The Visit'}
# {'M': 'The Vow'}
# {'M': 'The Wackness'}
# {'M': 'The Walk'}
# {'M': 'The Walking Deceased'}
# {'M': 'The Wash'}
# {'M': 'The Watch'}
# {'M': 'The Watcher'}
# {'M': 'The Waterboy'}
# {'M': 'The Way Way Back'}
# {'M': 'The Way of the Gun'}
# {'M': 'The Wedding Date'}
# {'M': 'The Wedding Planner'}
# {'M': 'The Whole Ten Yards'}
# {'M': 'The Wicked Within'}
# {'M': 'The Wild Bunch'}
# {'M': 'The Wild Thornberrys Movie'}
# {'M': 'The Wiz'}
# {'M': 'The Wizard of Oz'}
# {'M': 'The Wolf of Wall Street'}
# {'M': 'The Wolfman'}
# {'M': 'The Woman Chaser'}
# {'M': 'The Women'}
# {'M': 'The Wood'}
# {'M': 'The Words'}
# {'M': 'The Work and The Story'}
# {'M': 'The Work and the Glory II: American Zion'}
# {'M': 'The Wraith'}
# {'M': 'The Wrestler'}
# {'M': 'The Yards'}
# {'M': 'The Yellow Handkerchief'}
# {'M': 'The Young Messiah'}
# {'M': 'There Goes My Baby'}
# {'M': 'There Will Be Blood'}
# {'M': 'Theres Always Woodstock'}
# {'M': 'Theres Something About Mary'}
# {'M': 'Theresa Is a Mother'}
# {'M': 'They Came Together'}
# {'M': 'They Live'}
# {'M': 'They'}
# {'M': 'Things We Lost in the Fire'}
# {'M': 'Things to Do in Denver When Youre Dead'}
# {'M': 'Think Like a Man Too'}
# {'M': 'Think Like a Man'}
# {'M': 'Thinner'}
# {'M': 'Thirteen Conversations About One Thing'}
# {'M': 'Thirteen Days'}
# {'M': 'Thirteen'}
# {'M': 'This Christmas'}
# {'M': 'This Is 40'}
# {'M': 'This Is It'}
# {'M': 'This Is Martin Bonner'}
# {'M': 'This Is Where I Leave You'}
# {'M': 'This Is the End'}
# {'M': 'This Means War'}
# {'M': 'Thor'}
# {'M': 'Thor: The Dark World'}
# {'M': 'Three Kings'}
# {'M': 'Three Men and a Baby'}
# {'M': 'Thumbsucker'}
# {'M': 'Tiger Orange'}
# {'M': 'Tim and Erics Billion Dollar Movie'}
# {'M': 'Timber Falls'}
# {'M': 'Time Changer'}
# {'M': 'Time to Choose'}
# {'M': 'Timeline'}
# {'M': 'Tin Cup'}
# {'M': 'Tiny Furniture'}
# {'M': 'Titan A.E.'}
# {'M': 'Titanic'}
# {'M': 'To Die For'}
# {'M': 'To Kill a Mockingbird'}
# {'M': 'To Save A Life'}
# {'M': 'To Write Love on Her Arms'}
# {'M': 'Tombstone'}
# {'M': 'Tomcats'}
# {'M': 'Tomorrowland'}
# {'M': 'Tootsie'}
# {'M': 'Top Five'}
# {'M': 'Top Gun'}
# {'M': 'Top Hat'}
# {'M': 'Top Spin'}
# {'M': 'Topaz'}
# {'M': 'Torn Curtain'}
# {'M': 'Total Recall'}
# {'M': 'Tower Heist'}
# {'M': 'Toy Story 2'}
# {'M': 'Toy Story 3'}
# {'M': 'Toy Story'}
# {'M': 'Trade Of Innocents'}
# {'M': 'Trading Places'}
# {'M': 'Train'}
# {'M': 'Trainwreck'}
# {'M': 'Transamerica'}
# {'M': 'Transformers'}
# {'M': 'Transformers: Age of Extinction'}
# {'M': 'Transformers: Dark of the Moon'}
# {'M': 'Transformers: Revenge of the Fallen'}
# {'M': 'Trapeze'}
# {'M': 'Treasure Planet'}
# {'M': 'Trekkies'}
# {'M': 'Tremors'}
# {'M': 'Triple 9'}
# {'M': 'Trippin'}
# {'M': 'Troop Beverly Hills'}
# {'M': 'Tropic Thunder'}
# {'M': 'Trouble with the Curve'}
# {'M': 'Troy'}
# {'M': 'Trucker'}
# {'M': 'True Grit'}
# {'M': 'True Lies'}
# {'M': 'True Romance'}
# {'M': 'Trust the Man'}
# {'M': 'Trust'}
# {'M': 'Tuck Everlasting'}
# {'M': 'Tumbleweeds'}
# {'M': 'Tupac: Resurrection'}
# {'M': 'Turbo'}
# {'M': 'Turbulence'}
# {'M': 'Tusk'}
# {'M': 'Twilight Zone: The Movie'}
# {'M': 'Twilight'}
# {'M': 'Twins'}
# {'M': 'Twister'}
# {'M': 'Twixt'}
# {'M': 'Two Can Play That Game'}
# {'M': 'Two Girls and a Guy'}
# {'M': 'Tycoon'}
# {'M': 'U2 3D'}
# {'M': 'UHF'}
# {'M': 'Ulees Gold'}
# {'M': 'Ultraviolet'}
# {'M': 'Unbreakable'}
# {'M': 'Unbroken'}
# {'M': 'Under Siege 2: Dark Territory'}
# {'M': 'Under the Rainbow'}
# {'M': 'Underclassman'}
# {'M': 'Undercover Brother'}
# {'M': 'Underworld: Awakening'}
# {'M': 'Underworld: Evolution'}
# {'M': 'Underworld: Rise of the Lycans'}
# {'M': 'Undiscovered'}
# {'M': 'Undisputed'}
# {'M': 'Unfaithful'}
# {'M': 'Unfinished Business'}
# {'M': 'Unforgiven'}
# {'M': 'Unfriended'}
# {'M': 'Universal Soldier: The Return'}
# {'M': 'Unnatural'}
# {'M': 'Unstoppable'}
# {'M': 'Untraceable'}
# {'M': 'Up Close & Personal'}
# {'M': 'Up in the Air'}
# {'M': 'Up'}
# {'M': 'Vacation'}
# {'M': 'Valentine'}
# {'M': 'Valentines Day'}
# {'M': 'Vampire in Brooklyn'}
# {'M': 'Vampires Suck'}
# {'M': 'Vampires'}
# {'M': 'Vamps'}
# {'M': 'Vanilla Sky'}
# {'M': 'Vantage Point'}
# {'M': 'Varsity Blues'}
# {'M': 'VeggieTales: The Pirates Who Dont Do Anything'}
# {'M': 'Veronika Decides to Die'}
# {'M': 'Very Bad Things'}
# {'M': 'Vessel'}
# {'M': 'Vicky Cristina Barcelona'}
# {'M': 'Virtuosity'}
# {'M': 'Volcano'}
# {'M': 'W.'}
# {'M': 'WALL·E'}
# {'M': 'Wag the Dog'}
# {'M': 'Waiting for Guffman'}
# {'M': 'Waiting...'}
# {'M': 'Waitress'}
# {'M': 'Wal-Mart: The High Cost of Low Price'}
# {'M': 'Walk Hard: The Dewey Cox Story'}
# {'M': 'Walking Tall'}
# {'M': 'Wall Street'}
# {'M': 'Wall Street: Money Never Sleeps'}
# {'M': 'Walter'}
# {'M': 'Wanderlust'}
# {'M': 'War Horse'}
# {'M': 'War of the Worlds'}
# {'M': 'War'}
# {'M': 'WarGames'}
# {'M': 'Warlock'}
# {'M': 'Warlock: The Armageddon'}
# {'M': 'Warrior'}
# {'M': 'Watchmen'}
# {'M': 'Water for Elephants'}
# {'M': 'Waterworld'}
# {'M': 'Waynes World'}
# {'M': 'We Are Marshall'}
# {'M': 'We Bought a Zoo'}
# {'M': 'We Have Your Husband'}
# {'M': 'We Own the Night'}
# {'M': 'Welcome Home Roscoe Jenkins'}
# {'M': 'Welcome to the Dollhouse'}
# {'M': 'Welcome to the Rileys'}
# {'M': 'Wendy and Lucy'}
# {'M': 'Were No Angels'}
# {'M': 'Were the Millers'}
# {'M': 'West Side Story'}
# {'M': 'Western Religion'}
# {'M': 'What Happens in Vegas'}
# {'M': 'What Just Happened'}
# {'M': 'What Lies Beneath'}
# {'M': 'What Planet Are You From?'}
# {'M': 'What Women Want'}
# {'M': 'What a Girl Wants'}
# {'M': 'What the #$*! Do We (K)now!?'}
# {'M': 'What to Expect When Youre Expecting'}
# {'M': 'Whatever It Takes'}
# {'M': 'Whats Eating Gilbert Grape'}
# {'M': 'Whats Love Got to Do with It'}
# {'M': 'Whats Your Number?'}
# {'M': 'Whats the Worst That Could Happen?'}
# {'M': 'When Harry Met Sally...'}
# {'M': 'When a Stranger Calls'}
# {'M': 'When the Game Stands Tall'}
# {'M': 'Where the Heart Is'}
# {'M': 'Where the Truth Lies'}
# {'M': 'Where the Wild Things Are'}
# {'M': 'While Were Young'}
# {'M': 'Whip It'}
# {'M': 'Whiplash'}
# {'M': 'Whipped'}
# {'M': 'White Chicks'}
# {'M': 'White Fang'}
# {'M': 'White House Down'}
# {'M': 'White Squall'}
# {'M': 'Who Killed the Electric Car?'}
# {'M': 'Whos Your Caddy?'}
# {'M': 'Why Did I Get Married Too?'}
# {'M': 'Why Did I Get Married?'}
# {'M': 'Wicked Blood'}
# {'M': 'Wicker Park'}
# {'M': 'Wild Card'}
# {'M': 'Wild Hogs'}
# {'M': 'Wild Things'}
# {'M': 'Wild Wild West'}
# {'M': 'Wild'}
# {'M': 'Willard'}
# {'M': 'Willy Wonka & the Chocolate Factory'}
# {'M': 'Win a Date with Tad Hamilton!'}
# {'M': 'Wind Walkers'}
# {'M': 'Windsor Drive'}
# {'M': 'Windtalkers'}
# {'M': 'Winnie the Pooh'}
# {'M': 'Winter Passing'}
# {'M': 'Winters Bone'}
# {'M': 'Winters Tale'}
# {'M': 'Wish I Was Here'}
# {'M': 'Without Limits'}
# {'M': 'Without Men'}
# {'M': 'Without a Paddle'}
# {'M': 'Witless Protection'}
# {'M': 'Witness'}
# {'M': 'Wolf'}
# {'M': 'Woman Thou Art Loosed'}
# {'M': 'Woman on Top'}
# {'M': 'Wont Back Down'}
# {'M': 'Woo'}
# {'M': 'Woodstock'}
# {'M': 'World Trade Center'}
# {'M': 'World War Z'}
# {'M': 'Worlds Greatest Dad'}
# {'M': 'Wreck-It Ralph'}
# {'M': 'Wyatt Earp'}
# {'M': 'X-Men Origins: Wolverine'}
# {'M': 'X-Men'}
# {'M': 'X-Men: Apocalypse'}
# {'M': 'X-Men: First Class'}
# {'M': 'X2'}
# {'M': 'Year One'}
# {'M': 'Yes Man'}
# {'M': 'Yesterday Was a Lie'}
# {'M': 'Yoga Hosers'}
# {'M': 'Yogi Bear'}
# {'M': 'You Again'}
# {'M': 'You Can Count on Me'}
# {'M': 'You Cant Take It With You'}
# {'M': 'You Dont Mess with the Zohan'}
# {'M': 'You Got Served'}
# {'M': 'You Kill Me'}
# {'M': 'You Will Meet a Tall Dark Stranger'}
# {'M': 'You, Me and Dupree'}
# {'M': 'Young Adult'}
# {'M': 'Young Frankenstein'}
# {'M': 'Young Guns'}
# {'M': 'Young Sherlock Holmes'}
# {'M': 'Your Highness'}
# {'M': 'Your Sisters Sister'}
# {'M': 'Yours, Mine and Ours'}
# {'M': 'Youth in Revolt'}
# {'M': 'Youve Got Mail'}
# {'M': 'ZMD: Zombies of Mass Destruction'}
# {'M': 'Zack and Miri Make a Porno'}
# {'M': 'Zathura: A Space Adventure'}
# {'M': 'Zero Dark Thirty'}
# {'M': 'Zero Effect'}
# {'M': 'Zipper'}
# {'M': 'Zodiac'}
# {'M': 'Zombie Hunter'}
# {'M': 'Zombieland'}
# {'M': 'Zookeeper'}
# {'M': 'Zoolander 2'}
# {'M': 'Zoom'}
# {'M': 'xXx'}
# {'M': 'xXx: State of the Union'}
# {'M': 'Æon Flux'}

# %%
quer3 = prolog.query("same_director('Zodiac', M)")
for res3 in quer3: print(res3)
quer3.close()
# Out:
# {'M': 'Alien³'}
# {'M': 'Fight Club'}
# {'M': 'Gone Girl'}
# {'M': 'Panic Room'}
# {'M': 'Se7en'}
# {'M': 'The Curious Case of Benjamin Button'}
# {'M': 'The Game'}
# {'M': 'The Girl with the Dragon Tattoo'}
# {'M': 'The Social Network'}

# %%
quer4 = prolog.query("same_plot_2('Jason X', M)")
for res4 in quer4: print(res4)
quer4.close()
# Out:
# {'M': 'Aliens'}
# {'M': 'Event Horizon'}
# {'M': 'Galaxina'}
# {'M': 'Avatar'}
# {'M': 'Lockout'}
# {'M': 'Moon'}
# {'M': 'Renaissance'}
# {'M': 'Repo Man'}
# {'M': 'Interstellar'}
# {'M': 'Renaissance'}
# {'M': 'Repo Man'}
# {'M': 'Alien'}
# {'M': 'Aliens'}
# {'M': 'Armageddon'}
# {'M': 'Event Horizon'}
# {'M': 'Silent Running'}
# {'M': 'Space Chimps'}
# {'M': 'Treasure Planet'}
# {'M': 'Alien'}
# {'M': 'Armageddon'}
# {'M': 'Avatar'}
# {'M': 'Galaxina'}
# {'M': 'Interstellar'}
# {'M': 'Lockout'}
# {'M': 'Moon'}
# {'M': 'Silent Running'}
# {'M': 'Space Chimps'}
# {'M': 'Treasure Planet'}

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
def simple_recommender(movie,i = 2): #1<=i<=6, because we have created up to find_sim6 in the db.pl file
    assert 1 <= i <= 6
    s = set()
    quer = prolog.query("find_sim_" + str(i) + "('" + movie +"', L)")
    for res in quer:
      m = res['L']
      if m not in s:
        s.add(res['L'])
    quer.close()
    answers = s
    return answers

# %%
first_time=True
movie='Flyboys'
for i in range (6,0,-1): # we test a movie, on a declining order of similarity (high similarity grade means more similar)
  rec=simple_recommender(movie,i)
  if(first_time): 
    print(f"Movie name: {movie}\n")
    first_time=False
  print(f"Similarity grade: {i}\nList of similar movies: {list(rec)}\nNumber of similar movies found: {len(rec)}")
# Out:
# Movie name: Flyboys
#
# Similarity grade: 6
# List of similar movies: []
# Number of similar movies found: 0
# Similarity grade: 5
# List of similar movies: []
# Number of similar movies found: 0
# Similarity grade: 4
# List of similar movies: []
# Number of similar movies found: 0
# Similarity grade: 3
# List of similar movies: []
# Number of similar movies found: 0
# Similarity grade: 2
# List of similar movies: ['A Knights Tale', 'Supercross', 'The Horseman on the Roof', 'The Legend of Suriyothai', 'Young Sherlock Holmes', 'The Importance of Being Earnest', 'The Glimmer Man', 'The Twilight Saga: New Moon', 'Executive Decision', 'Tae Guk Gi: The Brotherhood of War', 'Cinderella Man', 'Rambo III', 'Operation Chromite', 'The Last Samurai', 'Sands of Iwo Jima', 'The Bounty', 'Baahubali: The Beginning', 'Rescue Dawn', 'First Blood', 'The Edge', 'Airlift', 'Cinco de Mayo: La Batalla', 'Gridiron Gang', 'The Greatest Show on Earth', 'Flight of the Phoenix', 'Crossroads', 'The Twilight Saga: Eclipse', 'Three Kingdoms: Resurrection of the Dragon', '47 Ronin', 'Beyond Borders', 'The Four Feathers', 'Bubble Boy', 'Free State of Jones', 'Patton', 'Hotel Rwanda', 'A Farewell to Arms', 'Apocalypto', 'The Marine', 'The Host', 'The Proposition', 'Tracker', 'City of Life and Death', 'Flags of Our Fathers', 'Nicholas Nickleby', 'Seven Years in Tibet', 'Tora! Tora! Tora!', 'The Great Raid', 'Tycoon', 'Flame & Citron', 'Ironclad', 'Winter in Wartime', 'The Great Escape', 'Southland Tales', 'Walking Tall', 'Shin Godzilla', 'Sweet Sweetbacks Baadasssss Song', 'The English Patient', 'Knowing', 'Maleficent', 'Lone Wolf McQuade', 'I Dreamed of Africa', 'Boom Town', 'From Here to Eternity', 'The Flowers of War', 'Young Guns', 'Behind Enemy Lines', 'Doctor Zhivago', 'Captain Corellis Mandolin', 'Mercy Streets', 'Crouching Tiger, Hidden Dragon', 'Kites', 'The Legend of the Lone Ranger', 'The Mortal Instruments: City of Bones', 'The Warlords', '12 Rounds', 'U-571', 'Gettysburg', 'In the Name of the King: A Dungeon Siege Tale', 'Twilight', 'Prince of Persia: The Sands of Time', 'Force 10 from Navarone', 'Dracula Untold', 'Alexander', 'The Last Legion', 'A Passage to India', 'All Is Lost', 'Tidal Wave', 'Flight of the Intruder', 'Amigo', 'The Lovers', 'Henry V', '300', 'A Tale of Three Cities', 'Proof of Life', 'The Other Side of Heaven', 'The Scarlet Letter', 'Legends of the Fall', 'March or Die', 'Alive', 'Kingdom of Heaven', 'Munich', 'The Quiet American', 'The Grandmaster', 'Downfall', 'Inchon', 'Top Gun', 'Congo', 'Ip Man 3', 'Kama Sutra - A Tale of Love', 'Caravans', 'Schindlers List', 'The Duchess', 'Twister', 'Highway', 'In the Land of Blood and Honey', 'Deuces Wild', 'The Fountain', 'The Assassin', 'The Finest Hours', 'September Dawn', 'The Perfect Wave', 'Beneath Hill 60', 'Fort McCoy', 'Passchendaele', 'Tears of the Sun', 'King Kong', 'Jonah: A VeggieTales Movie', 'The Land Girls', 'Sahara', 'Love & Basketball', 'The Legend of Hells Gate: An American Conspiracy', 'Gods and Generals', 'Hero', 'Lone Survivor', 'Action Jackson', 'Fighting Tommy Riley', 'Poseidon', 'The Big Parade', 'Extreme Ops', 'Joyeux Noël', 'The Messenger: The Story of Joan of Arc', 'Madison', 'Saints and Soldiers', 'The Train', 'Windtalkers', 'Cleopatra', 'Memoirs of a Geisha', 'Pompeii', 'Solomon and Sheba', 'The Twilight Saga: Breaking Dawn - Part 2', 'The Hunting Party', 'In the Heart of the Sea', 'The Count of Monte Cristo', 'Joe Dirt', 'Ladyhawke', 'A Guy Named Joe', 'The Negotiator', 'The Baader Meinhof Complex', 'The Young Victoria', 'First Knight', 'The Wind That Shakes the Barley', 'Quigley Down Under', 'Barry Lyndon', 'The Longest Day', 'The Devils Double', 'Six Days Seven Nights', 'Exodus: Gods and Kings', 'Fury', 'Inglourious Basterds', 'The Misfits', 'The Brothers Bloom', 'Nowhere to Run', 'The Saint', 'Braveheart', 'Silmido', 'Logans Run', 'Tombstone', 'Broken Arrow', 'Platoon', 'Arn: The Knight Templar', 'Across the Universe', 'Waterloo', 'In the Name of the King III', '1911', '13 Hours: The Secret Soldiers of Benghazi', 'The Blue Lagoon', 'Virgin Territory', 'Valkyrie', 'The Prisoner of Zenda', 'Robin and Marian', 'The Huntsman: Winters War', 'Bodyguards and Assassins', 'Black Hawk Down', 'One Mans Hero', 'Double Take', 'Rockaway', 'The Bridge on the River Kwai', 'Deep Impact', 'xXx: State of the Union', 'Troy', 'The Sorcerers Apprentice', 'Eliza ...
# Number of similar movies found: 264
# Similarity grade: 1
# List of similar movies: ['The Upside of Anger', 'Attack the Block', 'Asterix at the Olympic Games', 'Drive Angry', '25th Hour', 'Dolphin Tale', 'Walk the Line', 'The Last Castle', 'Shopgirl', 'Elizabeth', 'Superhero Movie', 'Trippin', 'Cinco de Mayo: La Batalla', 'Shotgun Stories', 'Arlington Road', 'Mission: Impossible II', 'Æon Flux', 'Bloodsport', 'Patton', '3000 Miles to Graceland', 'Hotel Rwanda', 'A Farewell to Arms', 'The Road to El Dorado', 'Hit & Run', 'Love Actually', 'Fast Five', 'Roll Bounce', 'Theres Something About Mary', 'Star Trek IV: The Voyage Home', 'Forbidden Kingdom', 'For Greater Glory - The True Story of Cristiada', 'Blackhat', 'Hands of Stone', 'The Great Escape', 'Lost in Translation', 'Tomorrowland', 'Knowing', '3 Ninjas Kick Back', 'The Exploding Girl', 'Mighty Joe Young', 'Elling', 'Boom Town', 'Departure', 'Lovely & Amazing', 'Planet of the Apes', 'O', 'After Earth', 'The Lovely Bones', 'The Wackness', 'Goldfinger', 'The Legend of the Lone Ranger', 'Trade Of Innocents', 'Boynton Beach Club', 'Babys Day Out', 'The Devil Wears Prada', 'Against the Wild', 'A Passage to India', 'The Transporter', 'The Wash', 'The Brave Little Toaster', 'Prison', 'A Woman, a Gun and a Noodle Shop', 'The Bad Lieutenant: Port of Call - New Orleans', '9', 'The Hobbit: The Battle of the Five Armies', 'Deep Blue Sea', 'Dancer, Texas Pop. 81', 'Insurgent', 'Little Women', 'On the Road', 'Lord of War', 'Gods Not Dead 2', 'Mystery Men', 'Namastey London', 'Interview with the Vampire', 'Next Day Air', '20,000 Leagues Under the Sea', 'Our Idiot Brother', 'Jurassic Park', 'Glitter', 'Men in Black II', 'Ultraviolet', 'Paparazzi', 'Gunless', 'Come Early Morning', 'Extreme Ops', 'The Last Witch Hunter', 'Days of Heaven', 'All Good Things', 'Saints and Soldiers', 'My Best Friends Girl', 'Wuthering Heights', 'Diary of a Mad Black Woman', 'Blade Runner', 'Children of Heaven', 'Bandidas', 'The Ugly Truth', 'Light Sleeper', 'Away We Go', 'Incident at Loch Ness', 'Madeas Witness Protection', 'Indignation', 'My Name Is Khan', 'The Art of Getting By', 'The Iron Lady', 'Alone With Her', 'Beyond the Valley of the Dolls', 'When Harry Met Sally...', 'Waterworld', 'Dom Hemingway', 'The Ballad of Jack and Rose', 'All the Kings Men', 'Death Race', 'Edmond', 'Mission: Impossible - Ghost Protocol', 'Moliere', 'Heartbreakers', 'True Grit', 'Across the Universe', 'The Last Godfather', '3 Backyards', 'In Good Company', 'The Statement', 'Resident Evil: Retribution', 'Mud', 'Jack Ryan: Shadow Recruit', 'The Valley of Decision', 'J. Edgar', 'The Marine 4: Moving Target', 'Good', 'When the Game Stands Tall', 'And So It Goes', 'Welcome to the Rileys', 'Burnt', 'Conan the Destroyer', 'Unstoppable', 'Twilight Zone: The Movie', 'The Beastmaster', 'Serenity', 'Monte Carlo', 'The Longshots', 'The Grey', 'Dragonball Evolution', 'Crank', 'Godsend', 'Saint Ralph', 'Inside Llewyn Davis', 'Peggy Sue Got Married', 'Ready to Rumble', 'The Reader', 'Brokeback Mountain', 'Concussion', 'Good Will Hunting', 'Mortal Kombat: Annihilation', 'Gangsters Paradise: Jerusalema', 'Disclosure', 'Pitch Black', 'Jakob the Liar', 'Once Upon a Time in America', 'Random Hearts', 'Maximum Risk', 'Cries and Whispers', 'Furious 7', 'The Adventures of Ford Fairlane', 'The Good German', 'Wristcutters: A Love Story', 'White Noise 2: The Light', 'The SpongeBob Movie: Sponge Out of Water', 'The Barbarian Invasions', 'BloodRayne', 'Anaconda', 'Moneyball', 'The Black Hole', 'Step Up Revolution', 'The Jacket', 'Three', 'The Robe', 'Heavens Gate', 'Hearts in Atlantis', 'Hancock', 'Pirates of the Caribbean: At Worlds End', 'Parker', 'The Banger Sisters', 'Epic', 'Mrs Henderson Presents', 'The Second Mother', 'Close Encounters of the Third Kind', 'Arthur and the Invisibles', 'We Are Your Friends', 'Ink', 'Danny Collins', 'Renaissance Man', 'Beauty Shop', 'The Mask of Zorro', 'West Side Story', 'Think Like a Man', 'Dry Spell', 'Rambo III', 'Wish I Was Here', 'Focus', 'Antarctica: A Year on Ice', 'Adore' ...
# Number of similar movies found: 3607

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i:i + 1 for i in range(1)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = simple_recommender(movie)

        for similar_movie in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[0]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[0] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10): # 10 experiments
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10) # 10 movies
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# precision: 0.26308006535947714
# recall: 0.0652777777777778
# f1: 0.10122572066710289
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 20) #20 movies
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.4520599786686743
# recall: 0.11805555555555555
# f1: 0.18359449854675092

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30) # 30 movies
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.45556975159311086
# recall: 0.16805555555555557
# f1: 0.2432111039451872

# %% [markdown]
# #### Άρα στη συγκεκριμένη περίπτωση έχουμε μεγαλύτερο precision για 30 ταινίες
